# %% [markdown]
# # Backtesting Reversal Strategies and Momentum Strategies on a Portfolio of S&P 500 Constituents

# %% [markdown]
# The aim of this python programme is to backtest reversal strategies and momentum strategies performed over a portfolio consisting of S&P 500 index (S&P 500) constituents. In this programme, reversal strategy means buying losers over the past period while momentum strategies means buying winners over the past period. Unlike those mentioned in academic journals, these strategies do not involve short-selling, considering the fact that most individuals are not able to perform short-selling. In this programme, we backtest a series of reversal strategies and a series of momentum strategies (differing by how we choose stocks to form a portfolio), as listed in the following:
#
# 1. Reversal strategy of buying losers (top 10 worst-performing stocks) over the past 5 years
# 2. Reversal strategy of buying losers over the past 3 years
# 3. Reversal strategy of buying losers over the past 1 year
# 4. Reversal strategy of buying the worst-performing stocks over the period of "60 months ago to 12 months ago"
# 5. Reversal strategy of buying losers over the past 1 month
# 6. Momentum strategy of buying winners (top 10 best-performing stocks) over the past 1 month
# 7. Momentum strategy of buying winners over the past 3 month
# 8. Momentum strategy of buying winners over the past 6 month
# 9. Momentum strategy of buying winners over the past 9 month,
# and also the following 2 strategies:
# 1. Momentum strategy of buying winners over the past 12 month
# 2. Momentum strategy of buying the best-performing stocks over the period of "12 months ago to 1 month ago"
#
# Every year at year-end (31/12), we rank the return of the constituents over a selected period in the past, based on the strategy we have chosen (e.g. the past 1 year, or the past 6 months, etc., referring to the strategies above). We then form a portfolio consisting of the top 10 stocks in the list, and hold it for 1 year. We compute this actual holding return.
#
# This programmes automatically downloads the historical price of the constituents from "Yahoo! Finance" website, for calculation and analysis.

# %%
import numpy as np
import pandas as pd
from datetime import datetime
import yfinance as yf
from sklearn import datasets, linear_model
from sklearn.metrics import mean_squared_error, r2_score

# %% [markdown]
# The following code cell is to get a list of "year-end S&P 500 constituents", from 2021 to 2007.

# %%
fhand = open('.\Documents\Stock\Backtests\SP_List.csv', 'r')
sp = []

for line in fhand:
    line = line.rstrip()
    line = line.split(',')
    #if line[0] == '2021':
    splst = []
    for i in line:
        if i != '':
            splst.append(i)
    sp.append(splst)
print(sp)        
        
fhand.close()
# Out:
# [['2022', 'MMM', 'AOS', 'ABT', 'ABBV', 'ACN', 'ATVI', 'ADM', 'ADBE', 'ADP', 'AAP', 'AES', 'AFL', 'A', 'APD', 'AKAM', 'ALK', 'ALB', 'ARE', 'ALGN', 'ALLE', 'LNT', 'ALL', 'GOOGL', 'GOOG', 'MO', 'AMZN', 'AMCR', 'AMD', 'AEE', 'AAL', 'AEP', 'AXP', 'AIG', 'AMT', 'AWK', 'AMP', 'ABC', 'AME', 'AMGN', 'APH', 'ADI', 'ANSS', 'AON', 'APA', 'AAPL', 'AMAT', 'APTV', 'ACGL', 'ANET', 'AJG', 'AIZ', 'T', 'ATO', 'ADSK', 'AZO', 'AVB', 'AVY', 'FRC', 'BKR', 'BALL', 'BAC', 'BBWI', 'BAX', 'BDX', 'WRB', 'BRK-B', 'BBY', 'BIO', 'TECH', 'BIIB', 'BLK', 'BK', 'BA', 'BKNG', 'BWA', 'BXP', 'BSX', 'BMY', 'AVGO', 'BR', 'BRO', 'BF-B', 'SBNY', 'CHRW', 'CDNS', 'CZR', 'CPT', 'CPB', 'COF', 'CAH', 'KMX', 'CCL', 'CARR', 'CTLT', 'CAT', 'CBOE', 'CBRE', 'CDW', 'CE', 'CNC', 'CNP', 'CDAY', 'CF', 'CRL', 'SCHW', 'CHTR', 'CVX', 'CMG', 'CB', 'CHD', 'CI', 'CINF', 'CTAS', 'CSCO', 'C', 'CFG', 'CLX', 'CME', 'CMS', 'KO', 'CTSH', 'CL', 'CMCSA', 'CMA', 'CAG', 'COP', 'ED', 'STZ', 'CEG', 'COO', 'CPRT', 'GLW', 'CTVA', 'CSGP', 'COST', 'CTRA', 'CCI', 'CSX', 'CMI', 'CVS', 'DHI', 'DHR', 'DRI', 'DVA', 'DE', 'DAL', 'XRAY', 'DVN', 'DXCM', 'FANG', 'DLR', 'DFS', 'DISH', 'DIS', 'DG', 'DLTR', 'D', 'DPZ', 'DOV', 'DOW', 'DTE', 'DUK', 'DD', 'DXC', 'EMN', 'ETN', 'EBAY', 'ECL', 'EIX', 'EW', 'EA', 'ELV', 'LLY', 'EMR', 'ENPH', 'ETR', 'EOG', 'EPAM', 'EQT', 'EFX', 'EQIX', 'EQR', 'ESS', 'EL', 'ETSY', 'RE', 'EVRG', 'ES', 'EXC', 'EXPE', 'EXPD', 'EXR', 'XOM', 'FFIV', 'FDS', 'LUMN', 'FAST', 'FRT', 'FDX', 'FITB', 'FSLR', 'FE', 'FIS', 'FISV', 'FLT', 'FMC', 'F', 'FTNT', 'FTV', 'FOXA', 'FOX', 'BEN', 'FCX', 'GRMN', 'IT', 'VNO', 'GEN', 'GNRC', 'GD', 'GE', 'GIS', 'GM', 'GPC', 'GILD', 'GL', 'GPN', 'GS', 'HAL', 'HIG', 'HAS', 'HCA', 'PEAK', 'HSIC', 'HSY', 'HES', 'HPE', 'HLT', 'HOLX', 'HD', 'HON', 'HRL', 'HST', 'HWM', 'HPQ', 'HUM', 'HBAN', 'HII', 'IBM', 'IEX', 'IDXX', 'ITW', 'ILMN', 'INCY', 'IR', 'SIVB', 'INTC', 'ICE', 'IFF', 'IP', 'IPG', 'INTU', 'ISRG', 'IVZ', 'INVH', 'IQV', 'IRM', 'JBHT', 'JKHY', 'J', 'JNJ', 'JCI', 'JPM', 'JNPR', 'K', 'KDP', 'KEY', 'KEYS', 'KMB', 'KIM', 'KMI', 'KLAC', 'KHC', 'KR', 'LHX', 'LH', 'LRCX', 'LW', 'LVS', 'LDOS', 'LEN', 'LNC', 'LIN', 'LYV', 'LKQ', 'LMT', 'L', 'LOW', 'LYB', 'MTB', 'MRO', 'MPC', 'MKTX', 'MAR', 'MMC', 'MLM', 'MAS', 'MA', 'MTCH', 'MKC', 'MCD', 'MCK', 'MDT', 'MRK', 'META', 'MET', 'MTD', 'MGM', 'MCHP', 'MU', 'MSFT', 'MAA', 'MRNA', 'MHK', 'MOH', 'TAP', 'MDLZ', 'MPWR', 'MNST', 'MCO', 'MS', 'MOS', 'MSI', 'MSCI', 'NDAQ', 'NTAP', 'NFLX', 'NWL', 'NEM', 'NWSA', 'NWS', 'NEE', 'NKE', 'NI', 'NDSN', 'NSC', 'NTRS', 'NOC', 'NCLH', 'NRG', 'NUE', 'NVDA', 'NVR', 'NXPI', 'ORLY', 'OXY', 'ODFL', 'OMC', 'ON', 'OKE', 'ORCL', 'OGN', 'OTIS', 'PCAR', 'PKG', 'PARA', 'PH', 'PAYX', 'PAYC', 'PYPL', 'PNR', 'PEP', 'PFE', 'PCG', 'PM', 'PSX', 'PNW', 'PXD', 'PNC', 'POOL', 'PPG', 'PPL', 'PFG', 'PG', 'PGR', 'PLD', 'PRU', 'PEG', 'PTC', 'PSA', 'PHM', 'QRVO', 'PWR', 'QCOM', 'DGX', 'RL', 'RJF', 'RTX', 'O', 'REG', 'REGN', 'RF', 'RSG', 'RMD', 'RVTY', 'RHI', 'ROK', 'ROL', 'ROP', 'ROST', 'RCL', 'SPGI', 'CRM', 'SBAC', 'SLB', 'STX', 'SEE', 'SRE', 'NOW', 'SHW', 'SPG', 'SWKS', 'SJM', 'SNA', 'SEDG', 'SO', 'LUV', 'SWK', 'SBUX', 'STT', 'STLD', 'STE', 'SYK', 'SYF', 'SNPS', 'SYY', 'TMUS', 'TROW', 'TTWO', 'TPR', 'TRGP', 'TGT', 'TEL', 'TDY', 'TFX', 'TER', 'TSLA', 'TXN', 'TXT', 'TMO', 'TJX', 'TSCO', 'TT', 'TDG', 'TRV', 'TRMB', 'TFC', 'TYL', 'TSN', 'USB', 'UDR', 'ULTA', 'UNP', 'UAL', 'UPS', 'URI', 'UNH', 'UHS', 'VLO', 'VTR', 'VRSN', 'VRSK', 'VZ', 'VRTX', 'VFC', 'VTRS', 'VICI', 'V', 'VMC', 'WAB', 'WBA', 'WMT', 'WBD', 'WM', 'WAT', 'WEC', 'WFC', 'WELL', 'WST', 'WDC', 'WRK', 'WY', 'WHR', 'WMB', 'WTW', 'GWW', 'WYNN', 'XEL', 'XYL', 'YUM', 'ZBRA', 'ZBH', 'ZION', 'ZTS'], ['2021', 'MMM', 'AOS', 'ABT', 'ABBV', 'ACN', 'ATVI', 'ADM', 'ADBE', 'ADP', 'AAP', 'AES', 'AFL', 'A', 'APD', 'AKAM', 'ALK', 'ALB', 'ARE', 'ALGN', 'ALLE', 'LNT', 'ALL', 'GOOGL', 'GOOG', 'MO', 'AMZN', 'AMCR', 'AMD', 'AEE', 'AAL', 'AEP', 'AXP', 'AIG', 'AMT', 'AWK', 'AMP', 'ABC', 'AME', 'AMGN', 'APH', 'ADI', 'ANSS', 'AON', 'APA', 'AAPL', 'AMAT', 'APTV', 'TWTR', 'ANET', 'AJG', 'AIZ', 'T', ...

# %% [markdown]
# The following code cell can be ignored. It is used to download monthly historical stock price at year-end ONE YEAR AT A TIME, and hence to backtest the performance of the portfolio ONE YEAR AT A TIME. This will be very slow. Use this cell code unless you want to backtest one year at a time.
#
# In the following example, historical adjusted stock price from 2016-12-01 to 2022-12-31 is downloaded. Then a portfolio consisting of the top 10 stock (based on the return from 2017-01-01 to 2021-12-31, i.e. past 5 years) is formed. In the middle of the code cell, there is a block of code to compute the Beta of each constituent based on adjusted stock price over the past 5 years. Lastly, the holding period (2022-01-01 to 2022-12-31) return is computed.

# %%
#Get the monthly adjusted closing stock price of S&P 500 constituents
st = yf.download(splst, 
                      start='2016-12-01', 
                      end='2022-12-31', 
                      progress=False,
                      interval="1mo",
).drop(columns = ['Open', 'High', 'Low', 'Close', 'Volume'], axis=1)

lst = np.log(st)
ri = lst.diff()
ri.index = pd.to_datetime(ri.index)
rihist = ri['Adj Close'].loc['2017-01-01':'2021-12-31'].dropna(axis='columns')
mean = rihist.mean(axis=0)*12
print(mean.sort_values(ascending=True)[0:10])

#Get the monthly adjusted closing stock price of S&P 500
sm = yf.download('^GSPC', 
                      start='2016-12-01', 
                      end='2022-12-31', 
                      progress=False,
                      interval="1mo",
).drop(columns = ['Open', 'High', 'Low', 'Close', 'Volume'], axis=1)
lsm = np.log(sm)
rm = lsm.diff()
rm.index = pd.to_datetime(rm.index)
rmhist = rm['Adj Close'].loc['2017-01-01':'2021-12-31']
rmhistnp = rmhist.to_numpy()
rmhistnp = rmhistnp.reshape(-1, 1)

# Create linear regression object
regr = linear_model.LinearRegression()

betas = []
for i in list(rihist.columns):
    rinp = np.array(rihist[i]).reshape(-1, 1)
    rinp = rinp.reshape(60,)
    rinp = rinp.reshape(-1, 1) 
    regr.fit(rmhistnp, rinp)
    beta = regr.coef_
    betas.append((beta, i))
betas.sort(reverse=True)
betalst = []
for i in betas[0:10]:
    betalst.append(i[1])
print(betalst)
    
stocklst = list(mean.sort_values(ascending=True)[0:10].index)
print(stocklst)
st.index = pd.to_datetime(st.index)
print(np.exp(ri['Adj Close'].loc['2022-01-01':'2022-12-31'][betalst].sum(axis=0)))
x = np.log((np.exp(ri['Adj Close'].loc['2022-01-01':'2022-12-31'][betalst].sum(axis=0)).sum(axis=0))/10)
print(x)

#with pd.ExcelWriter('Backtests_by_Python.xlsx') as writer:  
    #st.to_excel(writer, sheet_name='s')
    #ri.to_excel(writer, sheet_name='r')
    #mean.to_excel(writer, sheet_name='miu')
# Out:
# 12 Failed downloads:
# - NLSN: No timezone found, symbol may be delisted
# - CERN: No timezone found, symbol may be delisted
# - FISV: Data doesn't exist for startDate = 1480568400, endDate = 1672462800
# - FBHS: No timezone found, symbol may be delisted
# - XLNX: No timezone found, symbol may be delisted
# - PBCT: No timezone found, symbol may be delisted
# - CTXS: No timezone found, symbol may be delisted
# - TWTR: No timezone found, symbol may be delisted
# - DRE: No timezone found, symbol may be delisted
# - FRC: Data doesn't exist for startDate = 1480568400, endDate = 1672462800
# - INFO: No timezone found, symbol may be delisted
# - SIVB: No timezone found, symbol may be delisted
# VTRS   -0.205907
# GE     -0.185791
# AAL    -0.184227
# SLB    -0.171248
# CCL    -0.168484
# HAL    -0.151862
# APA    -0.151500
# PARA   -0.149150
# NCLH   -0.143629
# OXY    -0.139738
# dtype: float64
# ['APA', 'CZR', 'NCLH', 'MRO', 'DVN', 'HAL', 'RCL', 'OXY', 'PENN', 'FANG']
# ['VTRS', 'GE', 'AAL', 'SLB', 'CCL', 'HAL', 'APA', 'PARA', 'NCLH', 'OXY']
# APA     1.742689
# CZR     0.444777
# NCLH    0.590164
# MRO     1.654058
# DVN     1.419440
# HAL     1.730102
# RCL     0.642783
# OXY     2.173525
# PENN    0.572806
# FANG    1.268243
# dtype: float64
# 0.2020087052096112

# %% [markdown]
# The following code cell is to do the following things:
# 1. rank the constituents based on past return (as described before), for every year from 2007 year-end to 2021-year end,
# 2. carry out portfolio formation (as described before) at year-end,
# 3. compute the holding period return, for every year from 2008 year-end to 2022-year end.
#
# For the 11 strategies mentioned at the top, we make changes accordingly in the code cell below, and run this code cell repeatedly in order to complete our backtesting for these 11 strategies.
#
# In the following example, the "Reversal strategy of buying losers over the past 3 years" is backtested.

# %%
fhand = open('.\Documents\Stock\Backtests\SP_List.csv', 'r')
yrlst = ['2021', '2020', '2019', '2018', '2017', '2016', '2015', '2014', '2013', '2012', '2011', '2010', '2009', '2008', '2007']
yr = '2014'
result = []
for splst in sp[1:]:
    #for line in fhand:
        #line = line.rstrip()
        #line = line.split(',')
        #if line[0] == y:
            #splst = []
            #for i in line:
                #if i != '':
                    #splst.append(i)
    print(splst)
    
    #Please change the "years" and "months" in the follwing line accordingly, for each strategy.
    st = yf.download(splst, start=str(int(splst[0])-3)+'-12-01', end=str(int(splst[0])+1)+'-12-31', progress=False, interval="1mo",).drop(columns = ['Open', 'High', 'Low', 'Close', 'Volume'], axis=1)
    lst = np.log(st)
    ri = lst.diff()
    ri.index = pd.to_datetime(ri.index)
    #Please change the "years" and "months" in the follwing line accordingly, for each strategy.
    rihist = ri['Adj Close'].loc[str(int(splst[0])-2)+'-01-01':str(int(splst[0])-0)+'-12-31'].dropna(axis='columns')
    print(rihist.shape)
    mean = rihist.mean(axis=0)*12
    print(mean.sort_values(ascending=True)[0:10])
    stocklst = list(mean.sort_values(ascending=True)[0:10].index)
    print(stocklst)
    st.index = pd.to_datetime(st.index)
    x = np.log((np.exp(ri['Adj Close'].loc[str(int(splst[0])+1)+'-01-01':str(int(splst[0])+1)+'-12-31'][stocklst].sum(axis=0)).sum(axis=0))/10)
    print(x)
    result.append(x)
    print(result)

fhand.close()
# Out:
# ['2021', 'MMM', 'AOS', 'ABT', 'ABBV', 'ACN', 'ATVI', 'ADM', 'ADBE', 'ADP', 'AAP', 'AES', 'AFL', 'A', 'APD', 'AKAM', 'ALK', 'ALB', 'ARE', 'ALGN', 'ALLE', 'LNT', 'ALL', 'GOOGL', 'GOOG', 'MO', 'AMZN', 'AMCR', 'AMD', 'AEE', 'AAL', 'AEP', 'AXP', 'AIG', 'AMT', 'AWK', 'AMP', 'ABC', 'AME', 'AMGN', 'APH', 'ADI', 'ANSS', 'AON', 'APA', 'AAPL', 'AMAT', 'APTV', 'TWTR', 'ANET', 'AJG', 'AIZ', 'T', 'ATO', 'ADSK', 'AZO', 'AVB', 'AVY', 'FRC', 'BKR', 'BALL', 'BAC', 'BBWI', 'BAX', 'BDX', 'WRB', 'BRK-B', 'BBY', 'BIO', 'TECH', 'BIIB', 'BLK', 'BK', 'BA', 'BKNG', 'BWA', 'BXP', 'BSX', 'BMY', 'AVGO', 'BR', 'BRO', 'BF-B', 'SBNY', 'CHRW', 'CDNS', 'CZR', 'PBCT', 'CPB', 'COF', 'CAH', 'KMX', 'CCL', 'CARR', 'CTLT', 'CAT', 'CBOE', 'CBRE', 'CDW', 'CE', 'CNC', 'CNP', 'CDAY', 'CF', 'CRL', 'SCHW', 'CHTR', 'CVX', 'CMG', 'CB', 'CHD', 'CI', 'CINF', 'CTAS', 'CSCO', 'C', 'CFG', 'CLX', 'CME', 'CMS', 'KO', 'CTSH', 'CL', 'CMCSA', 'CMA', 'CAG', 'COP', 'ED', 'STZ', 'GPS', 'COO', 'CPRT', 'GLW', 'CTVA', 'PVH', 'COST', 'CTRA', 'CCI', 'CSX', 'CMI', 'CVS', 'DHI', 'DHR', 'DRI', 'DVA', 'DE', 'DAL', 'XRAY', 'DVN', 'DXCM', 'FANG', 'DLR', 'DFS', 'DISH', 'DIS', 'DG', 'DLTR', 'D', 'DPZ', 'DOV', 'DOW', 'DTE', 'DUK', 'DD', 'DXC', 'EMN', 'ETN', 'EBAY', 'ECL', 'EIX', 'EW', 'EA', 'ELV', 'LLY', 'EMR', 'ENPH', 'ETR', 'EOG', 'EPAM', 'DRE', 'EFX', 'EQIX', 'EQR', 'ESS', 'EL', 'ETSY', 'RE', 'EVRG', 'ES', 'EXC', 'EXPE', 'EXPD', 'EXR', 'XOM', 'FFIV', 'FDS', 'LUMN', 'FAST', 'FRT', 'FDX', 'FITB', 'FBHS', 'FE', 'FIS', 'FISV', 'FLT', 'FMC', 'F', 'FTNT', 'FTV', 'FOXA', 'FOX', 'BEN', 'FCX', 'GRMN', 'IT', 'VNO', 'GEN', 'GNRC', 'GD', 'GE', 'GIS', 'GM', 'GPC', 'GILD', 'GL', 'GPN', 'GS', 'HAL', 'HIG', 'HAS', 'HCA', 'PEAK', 'HSIC', 'HSY', 'HES', 'HPE', 'HLT', 'HOLX', 'HD', 'HON', 'HRL', 'HST', 'HWM', 'HPQ', 'HUM', 'HBAN', 'HII', 'IBM', 'IEX', 'IDXX', 'ITW', 'ILMN', 'INCY', 'IR', 'SIVB', 'INTC', 'ICE', 'IFF', 'IP', 'IPG', 'INTU', 'ISRG', 'IVZ', 'PENN', 'IQV', 'IRM', 'JBHT', 'JKHY', 'J', 'JNJ', 'JCI', 'JPM', 'JNPR', 'K', 'UA', 'KEY', 'KEYS', 'KMB', 'KIM', 'KMI', 'KLAC', 'KHC', 'KR', 'LHX', 'LH', 'LRCX', 'LW', 'LVS', 'LDOS', 'LEN', 'LNC', 'LIN', 'LYV', 'LKQ', 'LMT', 'L', 'LOW', 'LYB', 'MTB', 'MRO', 'MPC', 'MKTX', 'MAR', 'MMC', 'MLM', 'MAS', 'MA', 'MTCH', 'MKC', 'MCD', 'MCK', 'MDT', 'MRK', 'META', 'MET', 'MTD', 'MGM', 'MCHP', 'MU', 'MSFT', 'MAA', 'MRNA', 'MHK', 'INFO', 'TAP', 'MDLZ', 'MPWR', 'MNST', 'MCO', 'MS', 'MOS', 'MSI', 'MSCI', 'NDAQ', 'NTAP', 'NFLX', 'NWL', 'NEM', 'NWSA', 'NWS', 'NEE', 'NKE', 'NI', 'XLNX', 'NSC', 'NTRS', 'NOC', 'NCLH', 'NRG', 'NUE', 'NVDA', 'NVR', 'NXPI', 'ORLY', 'OXY', 'ODFL', 'OMC', 'IPGP', 'OKE', 'ORCL', 'OGN', 'OTIS', 'PCAR', 'PKG', 'PARA', 'PH', 'PAYX', 'PAYC', 'PYPL', 'PNR', 'PEP', 'PFE', 'CTXS', 'PM', 'PSX', 'PNW', 'PXD', 'PNC', 'POOL', 'PPG', 'PPL', 'PFG', 'PG', 'PGR', 'PLD', 'PRU', 'PEG', 'PTC', 'PSA', 'PHM', 'QRVO', 'PWR', 'QCOM', 'DGX', 'RL', 'RJF', 'RTX', 'O', 'REG', 'REGN', 'RF', 'RSG', 'RMD', 'RVTY', 'RHI', 'ROK', 'ROL', 'ROP', 'ROST', 'RCL', 'SPGI', 'CRM', 'SBAC', 'SLB', 'STX', 'SEE', 'SRE', 'NOW', 'SHW', 'SPG', 'SWKS', 'SJM', 'SNA', 'SEDG', 'SO', 'LUV', 'SWK', 'SBUX', 'STT', 'ABMD', 'STE', 'SYK', 'SYF', 'SNPS', 'SYY', 'TMUS', 'TROW', 'TTWO', 'TPR', 'NLSN', 'TGT', 'TEL', 'TDY', 'TFX', 'TER', 'TSLA', 'TXN', 'TXT', 'TMO', 'TJX', 'TSCO', 'TT', 'TDG', 'TRV', 'TRMB', 'TFC', 'TYL', 'TSN', 'USB', 'UDR', 'ULTA', 'UNP', 'UAL', 'UPS', 'URI', 'UNH', 'UHS', 'VLO', 'VTR', 'VRSN', 'VRSK', 'VZ', 'VRTX', 'VFC', 'VTRS', 'CERN', 'V', 'VMC', 'WAB', 'WBA', 'WMT', 'WBD', 'WM', 'WAT', 'WEC', 'WFC', 'WELL', 'WST', 'WDC', 'WRK', 'WY', 'WHR', 'WMB', 'WTW', 'GWW', 'WYNN', 'XEL', 'XYL', 'YUM', 'ZBRA', 'ZBH', 'ZION', 'ZTS']
#
# 13 Failed downloads:
# - NLSN: No timezone found, symbol may be delisted
# - CERN: No timezone found, symbol may be delisted
# - FISV: Data doesn't exist for startDate = 1543640400, endDate = 1672462800
# - FBHS: No timezone found, symbol may be delisted
# - XLNX: No timezone found, symbol may be delisted
# - PBCT: No timezone found, symbol may be delisted
# - CTXS: No timezone found, symbol may be delisted
# - TWTR: No timezone found, symbol may be delisted
# - DRE: No timezone found, symbol may be delisted
# - FRC: Data doesn't exist for startDate = 1543640400, endDate = 1672462800
# - INFO: No timezone found, symbol may be delisted
# - 2021: No timezone found, symbol may be delisted
# - SIVB: No timezone found, symbol may be delisted
# (36, 483)
# CCL    -0.281357
# NCLH   -0.238283
# VTRS   -0.227530
# UAL    -0.216140
# OXY    -0.213182
# AAL    -0.188327
# DXC    -0.153221
# BA     -0.147499
# GPS    -0.100524
# PARA   -0.100312
# dtype: float64
# ['CCL', 'NCLH', 'VTRS', 'UAL', 'OXY', 'AAL', 'DXC', 'BA', 'GPS', 'PARA']
# -0.14769898692233838
# [-0.14769898692233838]
# ['2020', 'MMM', 'AOS', 'ABT', 'ABBV', 'ACN', 'ATVI', 'ADM', 'ADBE', 'ADP', 'AAP', 'AES', 'AFL', 'A', 'APD', 'AKAM', 'ALK', 'ALB', 'ARE', 'ALGN', 'ALLE', 'LNT', 'ALL', 'GOOGL', 'GOOG', 'MO', 'AMZN', 'AMCR', 'AMD', 'AEE', 'AAL', 'AEP', 'AXP', 'AIG', 'AMT', 'AWK', 'AMP', 'ABC', 'AME', 'AMGN', 'APH', 'ADI', 'ANSS', 'AON', 'APA', 'AAPL', 'AMAT', 'APTV', 'TWTR', 'ANET', 'AJG', 'AIZ', 'T', 'ATO', 'ADSK', 'AZO', 'AVB', 'AVY', 'FRC', 'BKR', 'BALL', 'BAC', 'BBWI', 'BAX', 'BDX', 'WRB', 'BRK-B', 'BBY', 'BIO', 'MXIM', 'BIIB', 'BLK', 'BK', 'BA', 'BKNG', 'BWA', 'BXP', 'BSX', 'BMY', 'AVGO', 'BR', 'NOV', 'BF-B', 'LEG', 'CHRW', 'CDNS', 'VNT', 'PBCT', 'CPB', 'COF', 'CAH', 'KMX', 'CCL', 'CARR', 'CTLT', 'CAT', 'CBOE', 'CBRE', 'CDW', 'CE', 'CNC', 'CNP', 'UNM', 'CF', 'FLIR', 'SCHW', 'CHTR', 'CVX', 'CMG', 'CB', 'CHD', 'CI', 'CINF', 'CTAS', 'CSCO', 'C', 'CFG', 'CLX', 'CME', 'CMS', 'KO', 'CTSH', 'CL', 'CMCSA', 'CMA', 'CAG', 'COP', 'ED', 'STZ', 'GPS', 'COO', 'CPRT', 'GLW', 'CTVA', 'PVH', 'COST', 'CTRA', 'CCI', 'CSX', 'CMI', 'CVS', 'DHI', 'DHR', 'DRI', 'DVA', 'DE', 'DAL', 'XRAY', 'DVN', 'DXCM', 'FANG', 'DLR', 'DFS', 'DISH', 'DIS', 'DG', 'DLTR', 'D', 'DPZ', 'DOV', 'DOW', 'DTE', 'DUK', 'DD', 'DXC', 'EMN', 'ETN', 'EBAY', 'ECL', 'EIX', 'EW', 'EA', 'ELV', 'LLY', 'EMR', 'TIF', 'ETR', 'EOG', 'KSU', 'DRE', 'EFX', 'EQIX', 'EQR', 'ESS', 'EL', 'ETSY', 'RE', 'EVRG', 'ES', 'EXC', 'EXPE', 'EXPD', 'EXR', 'XOM', 'FFIV', 'WU', 'LUMN', 'FAST', 'FRT', 'FDX', 'FITB', 'FBHS', 'FE', 'FIS', 'FISV', 'FLT', 'FMC', 'F', 'FTNT', 'FTV', 'FOXA', 'FOX', 'BEN', 'FCX', 'GRMN', 'IT', 'VNO', 'GEN', 'XRX', 'GD', 'GE', 'GIS', 'GM', 'GPC', 'GILD', 'GL', 'GPN', 'GS', 'HAL', 'HIG', 'HAS', 'HCA', 'PEAK', 'HSIC', 'HSY', 'HES', 'HPE', 'HLT', 'HOLX', 'HD', 'HON', 'HRL', 'HST', 'HWM', 'HPQ', 'HUM', 'HBAN', 'HII', 'IBM', 'IEX', 'IDXX', 'ITW', 'ILMN', 'INCY', 'IR', 'SIVB', 'INTC', 'ICE', 'IFF', 'IP', 'IPG', 'INTU', 'ISRG', 'IVZ', 'SLG', 'IQV', 'IRM', 'JBHT', 'JKHY', 'J', 'JNJ', 'JCI', 'JPM', 'JNPR', 'K', 'UA', 'KEY', 'KEYS', 'KMB', 'KIM', 'KMI', 'KLAC', 'KHC', 'KR', 'LHX', 'LH', 'LRCX', 'LW', 'LVS', 'LDOS', 'LEN', 'LNC', 'LIN', 'LYV', 'LKQ', 'LMT', 'L', 'LOW', 'LYB', 'MTB', 'MRO', 'MPC', 'MKTX', 'MAR', 'MMC', 'MLM', 'MAS', 'MA', 'PRGO', 'MKC', 'MCD', 'MCK', 'MDT', 'MRK', 'META', 'MET', 'MTD', 'MGM', 'MCHP', 'MU', 'MSFT', 'MAA', 'ALXN', 'MHK', 'INFO', 'TAP', 'MDLZ', 'FTI', 'MNST', 'MCO', 'MS', 'MOS', 'MSI', 'MSCI', 'NDAQ', 'NTAP', 'NFLX', 'NWL', 'NEM', 'NWSA', 'NWS', 'NEE', 'NKE', 'NI', 'XLNX', 'NSC', 'NTRS', 'NOC', 'NCLH', 'NRG', 'NUE', 'NVDA', 'NVR', 'FLS', 'ORLY', 'OXY', 'ODFL', 'OMC', 'IPGP', 'OKE', 'ORCL', 'HFC', 'OTIS', 'PCAR', 'PKG', 'PARA', 'PH', 'PAYX', 'PAYC', 'PYPL', 'PNR', 'PEP', 'PFE', 'CTXS', 'PM', 'PSX', 'PNW', 'PXD', 'PNC', 'POOL', 'PPG', 'PPL', 'PFG', 'PG', 'PGR', 'PLD', 'PRU', 'PEG', 'VAR', 'PSA', 'PHM', 'QRVO', 'PWR', 'QCOM', 'DGX', 'RL', 'RJF', 'RTX', 'O', 'REG', 'REGN', 'RF', 'RSG', 'RMD', 'RVTY', 'RHI', 'ROK', 'ROL', 'ROP', 'ROST', 'RCL', 'SPGI', 'CRM', 'SBAC', 'SLB', 'STX', 'SEE', 'SRE', 'NOW', 'SHW', 'SPG', 'SWKS', 'SJM', 'SNA', 'HBI', 'SO', 'LUV', 'SWK', 'SBUX', 'STT', 'ABMD', 'STE', 'SYK', 'SYF', 'SNPS', 'SYY', 'TMUS', 'TROW', 'TTWO', 'TPR', 'NLSN', 'TGT', 'TEL', 'TDY', 'TFX', 'TER', 'TSLA', 'TXN', 'TXT', 'TMO', 'TJX', 'TSCO', 'TT', 'TDG', 'TRV', 'CXO', 'TFC', 'TYL', 'TSN', 'USB', 'UDR', 'ULTA', 'UNP', 'UAL', 'UPS', 'URI', 'UNH', 'UHS', 'VLO', 'VTR', 'VRSN', 'VRSK', 'VZ', 'VRTX', 'VFC', 'VTRS', 'CERN', 'V', 'VMC', 'WAB', 'WBA', 'WMT', 'WBD', 'WM', 'WAT', 'WEC', 'WFC', 'WELL', 'WST', 'WDC', 'WRK', 'WY', 'WHR', 'WMB', 'WTW', 'GWW', 'WYNN', 'XEL', 'XYL', 'YUM', 'ZBRA', 'ZBH', 'ZION', 'ZTS']
# 21 Failed downloads:
# - HFC: No timezone found, symbol may be delisted
# - KSU: No timezone found, symbol may be delisted
# - NLSN: No timezone found, symbol may be delisted
# - MXIM: No timezone found, symbol may be delisted
# - CERN: No timezone found, symbol may be delisted
# - FISV: Data doesn't exist for startDate = 1512104400, endDate = 1640926800
# - FBHS: No timezone found, symbol may be delisted
# - XLNX: No timezone found, symbol may be delisted
# - VAR: No timezone found, symbol may be delisted
# - ALXN: No timezone found, symbol may be delisted
# - CXO: No timezone found, symbol may be delisted
# - 2020: No timezone found, symbol may be delisted
# - PBCT: No timezone found, symbol may be delisted
# - CTXS: No timezone found, symbol may be delisted
# - TWTR: No timezone found, symbol may be delisted
# - TIF: No timezone found, symbol may be delisted
# - DRE: No timezone found, symbol may be delisted
# - FRC: Data doesn't exist for startDate = 1512104400, endDate = 1640926800
# - INFO: No timezone found, symbol may be delisted
# - SIVB: No timezone found, symbol may be delisted
# - FLIR: No timezone found, symbol may be delisted
# (36, 476)
# OXY    -0.432368
# AAL    -0.389350
# FTI    -0.380256
# DXC    -0.369746
# CCL    -0.345630
# APA    -0.338596
# SLB    -0.334396
# NOV    -0.314798
# FANG   -0.304298
# MRO    -0.298635
# dtype: float64
# ['OXY', 'AAL', 'FTI', 'DXC', 'CCL', 'APA', 'SLB', 'NOV', 'FANG', 'MRO']
# 0.3996787968108296
# [-0.14769898692233838, 0.3996787968108296]
# ['2019', 'MMM', 'AOS', 'ABT', 'ABBV', 'ACN', 'ATVI', 'ADM', 'ADBE', 'ADP', 'AAP', 'AES', 'AFL', 'A', 'APD', 'AKAM', 'ALK', 'ALB', 'ARE', 'ALGN', 'ALLE', 'LNT', 'ALL', 'GOOGL', 'GOOG', 'MO', 'AMZN', 'AMCR', 'AMD', 'AEE', 'AAL', 'AEP', 'AXP', 'AIG', 'AMT', 'AWK', 'AMP', 'ABC', 'AME', 'AMGN', 'APH', 'ADI', 'ANSS', 'AON', 'APA', 'AAPL', 'AMAT', 'APTV', 'TWTR', 'ANET', 'AJG', 'AIZ', 'T', 'ATO', 'ADSK', 'AZO', 'AVB', 'AVY', 'FRC', 'BKR', 'BALL', 'BAC', 'BBWI', 'BAX', 'BDX', 'WRB', 'BRK-B', 'BBY', 'ADS', 'MXIM', 'BIIB', 'BLK', 'BK', 'BA', 'BKNG', 'BWA', 'BXP', 'BSX', 'BMY', 'AVGO', 'BR', 'NOV', 'BF-B', 'LEG', 'CHRW', 'CDNS', 'NBL', 'PBCT', 'CPB', 'COF', 'CAH', 'KMX', 'CCL', 'RTN', 'KSS', 'CAT', 'CBOE', 'CBRE', 'CDW', 'CE', 'CNC', 'CNP', 'UNM', 'CF', 'FLIR', 'SCHW', 'CHTR', 'CVX', 'CMG', 'CB', 'CHD', 'CI', 'CINF', 'CTAS', 'CSCO', 'C', 'CFG', 'CLX', 'CME', 'CMS', 'KO', 'CTSH', 'CL', 'CMCSA', 'CMA', 'CAG', 'COP', 'ED', 'STZ', 'GPS', 'COO', 'CPRT', 'GLW', 'CTVA', 'PVH', 'COST', 'CTRA', 'CCI', 'CSX', 'CMI', 'CVS', 'DHI', 'DHR', 'DRI', 'DVA', 'DE', 'DAL', 'XRAY', 'DVN', 'AGN', 'FANG', 'DLR', 'DFS', 'DISH', 'DIS', 'DG', 'DLTR', 'D', 'CPRI', 'DOV', 'DOW', 'DTE', 'DUK', 'DD', 'DXC', 'EMN', 'ETN', 'EBAY', 'ECL', 'EIX', 'EW', 'EA', 'ELV', 'LLY', 'EMR', 'TIF', 'ETR', 'EOG', 'KSU', 'DRE', 'EFX', 'EQIX', 'EQR', 'ESS', 'EL', 'HRB', 'RE', 'EVRG', 'ES', 'EXC', 'EXPE', 'EXPD', 'EXR', 'XOM', 'FFIV', 'WU', 'LUMN', 'FAST', 'FRT', 'FDX', 'FITB', 'FBHS', 'FE', 'FIS', 'FISV', 'FLT', 'FMC', 'F', 'FTNT', 'FTV', 'FOXA', 'FOX', 'BEN', 'FCX', 'GRMN', 'IT', 'VNO', 'GEN', 'XRX', 'GD', 'GE', 'GIS', 'GM', 'GPC', 'GILD', 'GL', 'GPN', 'GS', 'HAL', 'HIG', 'HAS', 'HCA', 'PEAK', 'HSIC', 'HSY', 'HES', 'HPE', 'HLT', 'HOLX', 'HD', 'HON', 'HRL', 'HST', 'ARNC', 'HPQ', 'HUM', 'HBAN', 'HII', 'IBM', 'IEX', 'IDXX', 'ITW', 'ILMN', 'INCY', 'XEC', 'SIVB', 'INTC', 'ICE', 'IFF', 'IP', 'IPG', 'INTU', 'ISRG', 'IVZ', 'SLG', 'IQV', 'IRM', 'JBHT', 'JKHY', 'J', 'JNJ', 'JCI', 'JPM', 'JNPR', 'K', 'UA', 'KEY', 'KEYS', 'KMB', 'KIM', 'KMI', 'KLAC', 'KHC', 'KR', 'LHX', 'LH', 'LRCX', 'LW', 'LVS', 'LDOS', 'LEN', 'LNC', 'LIN', 'LYV', 'LKQ', 'LMT', 'L', 'LOW', 'LYB', 'MTB', 'MRO', 'MPC', 'MKTX', 'MAR', 'MMC', 'MLM', 'MAS', 'MA', 'PRGO', 'MKC', 'MCD', 'MCK', 'MDT', 'MRK', 'META', 'MET', 'MTD', 'MGM', 'MCHP', 'MU', 'MSFT', 'MAA', 'ALXN', 'MHK', 'INFO', 'TAP', 'MDLZ', 'FTI', 'MNST', 'MCO', 'MS', 'MOS', 'MSI', 'MSCI', 'NDAQ', 'NTAP', 'NFLX', 'NWL', 'NEM', 'NWSA', 'NWS', 'NEE', 'NKE', 'NI', 'XLNX', 'NSC', 'NTRS', 'NOC', 'NCLH', 'NRG', 'NUE', 'NVDA', 'NVR', 'FLS', 'ORLY', 'OXY', 'ODFL', 'OMC', 'IPGP', 'OKE', 'ORCL', 'HFC', 'M', 'PCAR', 'PKG', 'PARA', 'PH', 'PAYX', 'WCG', 'PYPL', 'PNR', 'PEP', 'PFE', 'CTXS', 'PM', 'PSX', 'PNW', 'PXD', 'PNC', 'ETFC', 'PPG', 'PPL', 'PFG', 'PG', 'PGR', 'PLD', 'PRU', 'PEG', 'VAR', 'PSA', 'PHM', 'QRVO', 'PWR', 'QCOM', 'DGX', 'RL', 'RJF', 'RTX', 'O', 'REG', 'REGN', 'RF', 'RSG', 'RMD', 'RVTY', 'RHI', 'ROK', 'ROL', 'ROP', 'ROST', 'RCL', 'SPGI', 'CRM', 'SBAC', 'SLB', 'STX', 'SEE', 'SRE', 'NOW', 'SHW', 'SPG', 'SWKS', 'SJM', 'SNA', 'HBI', 'SO', 'LUV', 'SWK', 'SBUX', 'STT', 'ABMD', 'STE', 'SYK', 'SYF', 'SNPS', 'SYY', 'TMUS', 'TROW', 'TTWO', 'TPR', 'NLSN', 'TGT', 'TEL', 'HOG', 'TFX', 'COTY', 'AIV', 'TXN', 'TXT', 'TMO', 'TJX', 'TSCO', 'TT', 'TDG', 'TRV', 'CXO', 'TFC', 'JWN', 'TSN', 'USB', 'UDR', 'ULTA', 'UNP', 'UAL', 'UPS', 'URI', 'UNH', 'UHS', 'VLO', 'VTR', 'VRSN', 'VRSK', 'VZ', 'VRTX', 'VFC', 'VTRS', 'CERN', 'V', 'VMC', 'WAB', 'WBA', 'WMT', 'WBD', 'WM', 'WAT', 'WEC', 'WFC', 'WELL', 'HP', 'WDC', 'WRK', 'WY', 'WHR', 'WMB', 'WTW', 'GWW', 'WYNN', 'XEL', 'XYL', 'YUM', 'ZBRA', 'ZBH', 'ZION', 'ZTS']
#
# 28 Failed downloads:
# - ETFC: No timezone found, symbol may be delisted
# - HFC: No timezone found, symbol may be delisted
# - KSU: No timezone found, symbol may be delisted
# - XEC: No timezone found, symbol may be delisted
# - NLSN: No timezone found, symbol may be delisted
# - 2019: No timezone found, symbol may be delisted
# - MXIM: No timezone found, symbol may be delisted
# - CERN: No timezone found, symbol may be delisted
# - WCG: No timezone found, symbol may be delisted
# - FISV: Data doesn't exist for startDate = 1480568400, endDate = 1609390800
# - FBHS: No timezone found, symbol may be delisted
# - XLNX: No timezone found, symbol may be delisted
# - ALXN: No timezone found, symbol may be delisted
# - VAR: No timezone found, symbol may be delisted
# - RTN: No timezone found, symbol may be delisted
# - NBL: No timezone found, symbol may be delisted
# - CXO: No timezone found, symbol may be delisted
# - PBCT: No timezone found, symbol may be delisted
# - CTXS: No timezone found, symbol may be delisted
# - TWTR: No timezone found, symbol may be delisted
# - TIF: No timezone found, symbol may be delisted
# - AGN: No timezone found, symbol may be delisted
# - DRE: No timezone found, symbol may be delisted
# - FRC: Data doesn't exist for startDate = 1480568400, endDate = 1609390800
# - INFO: No timezone found, symbol may be delisted
# - SIVB: No timezone found, symbol may be delisted
# - ADS: No timezone found, symbol may be delisted
# - FLIR: No timezone found, symbol may be delisted
# (36, 471)
# BBWI   -0.371029
# GE     -0.309965
# KHC    -0.291573
# APA    -0.276246
# HAL    -0.243999
# NWL    -0.242596
# VTRS   -0.213602
# SLB    -0.209059
# M      -0.191766
# DVN    -0.179373
# dtype: float64
# ['BBWI', 'GE', 'KHC', 'APA', 'HAL', 'NWL', 'VTRS', 'SLB', 'M', 'DVN']
# -0.04495962534446742
# [-0.14769898692233838, 0.3996787968108296, -0.04495962534446742]
# ['2018', 'MMM', 'AOS', 'ABT', 'ABBV', 'ACN', 'ATVI', 'ADM', 'ADBE', 'ADP', 'AAP', 'AES', 'AFL', 'A', 'APD', 'AKAM', 'ALK', 'ALB', 'ARE', 'ALGN', 'ALLE', 'LNT', 'ALL', 'GOOGL', 'GOOG', 'MO', 'AMZN', 'MAT', 'AMD', 'AEE', 'AAL', 'AEP', 'AXP', 'AIG', 'AMT', 'AWK', 'AMP', 'ABC', 'AME', 'AMGN', 'APH', 'ADI', 'ANSS', 'AON', 'APA', 'AAPL', 'AMAT', 'APTV', 'TWTR', 'ANET', 'AJG', 'AIZ', 'T', 'NFX', 'ADSK', 'AZO', 'AVB', 'AVY', 'SCG', 'BKR', 'BALL', 'BAC', 'BBWI', 'BAX', 'BDX', 'VIAB', 'BRK-B', 'BBY', 'ADS', 'MXIM', 'BIIB', 'BLK', 'BK', 'BA', 'BKNG', 'BWA', 'BXP', 'BSX', 'BMY', 'AVGO', 'BR', 'NOV', 'BF-B', 'LEG', 'CHRW', 'CDNS', 'NBL', 'PBCT', 'CPB', 'COF', 'CAH', 'KMX', 'CCL', 'RTN', 'KSS', 'CAT', 'CBOE', 'CBRE', 'TSS', 'CE', 'CNC', 'CNP', 'UNM', 'CF', 'FLIR', 'SCHW', 'CHTR', 'CVX', 'CMG', 'CB', 'CHD', 'CI', 'CINF', 'CTAS', 'CSCO', 'C', 'CFG', 'CLX', 'CME', 'CMS', 'KO', 'CTSH', 'CL', 'CMCSA', 'CMA', 'CAG', 'COP', 'ED', 'STZ', 'GPS', 'COO', 'CPRT', 'GLW', 'FLR', 'PVH', 'COST', 'CTRA', 'CCI', 'CSX', 'CMI', 'CVS', 'DHI', 'DHR', 'DRI', 'DVA', 'DE', 'DAL', 'XRAY', 'DVN', 'AGN', 'FANG', 'DLR', 'DFS', 'DISH', 'DIS', 'DG', 'DLTR', 'D', 'CPRI', 'DOV', 'BHF', 'DTE', 'DUK', 'DWDP', 'DXC', 'EMN', 'ETN', 'EBAY', 'ECL', 'EIX', 'EW', 'EA', 'ELV', 'LLY', 'EMR', 'TIF', 'ETR', 'EOG', 'KSU', 'DRE', 'EFX', 'EQIX', 'EQR', 'ESS', 'EL', 'HRB', 'RE', 'EVRG', 'ES', 'EXC', 'EXPE', 'EXPD', 'EXR', 'XOM', 'FFIV', 'WU', 'LUMN', 'FAST', 'FRT', 'FDX', 'FITB', 'FBHS', 'FE', 'FIS', 'FISV', 'FLT', 'FMC', 'F', 'FTNT', 'FTV', 'FOXA', 'FOX', 'BEN', 'FCX', 'GRMN', 'IT', 'VNO', 'GEN', 'XRX', 'GD', 'GE', 'GIS', 'GM', 'GPC', 'GILD', 'GL', 'GPN', 'GS', 'HAL', 'HIG', 'HAS', 'HCA', 'PEAK', 'HSIC', 'HSY', 'HES', 'HPE', 'HLT', 'HOLX', 'HD', 'HON', 'HRL', 'HST', 'ARNC', 'HPQ', 'HUM', 'HBAN', 'HII', 'IBM', 'FL', 'IDXX', 'ITW', 'ILMN', 'INCY', 'XEC', 'SIVB', 'INTC', 'ICE', 'IFF', 'IP', 'IPG', 'INTU', 'ISRG', 'IVZ', 'SLG', 'IQV', 'IRM', 'JBHT', 'JKHY', 'J', 'JNJ', 'JCI', 'JPM', 'JNPR', 'K', 'UA', 'KEY', 'KEYS', 'KMB', 'KIM', 'KMI', 'KLAC', 'KHC', 'KR', 'LHX', 'LH', 'LRCX', 'LW', 'NKTR', 'APC', 'LEN', 'LNC', 'LIN', 'AMG', 'LKQ', 'LMT', 'L', 'LOW', 'LYB', 'MTB', 'MRO', 'MPC', 'LLL', 'MAR', 'MMC', 'MLM', 'MAS', 'MA', 'PRGO', 'MKC', 'MCD', 'MCK', 'MDT', 'MRK', 'META', 'MET', 'MTD', 'MGM', 'MCHP', 'MU', 'MSFT', 'MAA', 'ALXN', 'MHK', 'INFO', 'TAP', 'MDLZ', 'FTI', 'MNST', 'MCO', 'MS', 'MOS', 'MSI', 'MSCI', 'NDAQ', 'NTAP', 'NFLX', 'NWL', 'NEM', 'NWSA', 'NWS', 'NEE', 'NKE', 'NI', 'XLNX', 'NSC', 'NTRS', 'NOC', 'NCLH', 'NRG', 'NUE', 'NVDA', 'JEF', 'FLS', 'ORLY', 'OXY', 'STI', 'OMC', 'IPGP', 'OKE', 'ORCL', 'HFC', 'M', 'PCAR', 'PKG', 'PARA', 'PH', 'PAYX', 'WCG', 'PYPL', 'PNR', 'PEP', 'PFE', 'CTXS', 'PM', 'PSX', 'PNW', 'PXD', 'PNC', 'ETFC', 'PPG', 'PPL', 'PFG', 'PG', 'PGR', 'PLD', 'PRU', 'PEG', 'VAR', 'PSA', 'PHM', 'QRVO', 'PWR', 'QCOM', 'DGX', 'RL', 'RJF', 'RTX', 'O', 'REG', 'REGN', 'RF', 'RSG', 'RMD', 'RVTY', 'RHI', 'ROK', 'ROL', 'ROP', 'ROST', 'RCL', 'SPGI', 'CRM', 'SBAC', 'SLB', 'STX', 'SEE', 'SRE', 'CELG', 'SHW', 'SPG', 'SWKS', 'SJM', 'SNA', 'HBI', 'SO', 'LUV', 'SWK', 'SBUX', 'STT', 'ABMD', 'MAC', 'SYK', 'SYF', 'SNPS', 'SYY', 'RHT', 'TROW', 'TTWO', 'TPR', 'NLSN', 'TGT', 'TEL', 'HOG', 'PCG', 'COTY', 'AIV', 'TXN', 'TXT', 'TMO', 'TJX', 'TSCO', 'TT', 'TDG', 'TRV', 'CXO', 'TFC', 'JWN', 'TSN', 'USB', 'UDR', 'ULTA', 'UNP', 'UAL', 'UPS', 'URI', 'UNH', 'UHS', 'VLO', 'VTR', 'VRSN', 'VRSK', 'VZ', 'VRTX', 'VFC', 'VTRS', 'CERN', 'V', 'VMC', 'GT', 'WBA', 'WMT', 'WBD', 'WM', 'WAT', 'WEC', 'WFC', 'WELL', 'HP', 'WDC', 'WRK', 'WY', 'WHR', 'WMB', 'WTW', 'GWW', 'WYNN', 'XEL', 'XYL', 'YUM', 'TRIP', 'ZBH', 'ZION', 'ZTS']
# 38 Failed downloads:
# - ETFC: No timezone found, symbol may be delisted
# - HFC: No timezone found, symbol may be delisted
# - KSU: No timezone found, symbol may be delisted
# - VIAB: No timezone found, symbol may be delisted
# - XEC: No timezone found, symbol may be delisted
# - NLSN: No timezone found, symbol may be delisted
# - MXIM: No timezone found, symbol may be delisted
# - CERN: No timezone found, symbol may be delisted
# - WCG: No timezone found, symbol may be delisted
# - FISV: Data doesn't exist for startDate = 1448946000, endDate = 1577768400
# - FBHS: No timezone found, symbol may be delisted
# - CELG: No timezone found, symbol may be delisted
# - XLNX: No timezone found, symbol may be delisted
# - LLL: No timezone found, symbol may be delisted
# - SCG: No data found for this date range, symbol may be delisted
# - VAR: No timezone found, symbol may be delisted
# - ALXN: No timezone found, symbol may be delisted
# - NFX: No data found for this date range, symbol may be delisted
# - RTN: No timezone found, symbol may be delisted
# - DWDP: No timezone found, symbol may be delisted
# - NBL: No timezone found, symbol may be delisted
# - TSS: No timezone found, symbol may be delisted
# - CXO: No timezone found, symbol may be delisted
# - PBCT: No timezone found, symbol may be delisted
# - CTXS: No timezone found, symbol may be delisted
# - TWTR: No timezone found, symbol may be delisted
# - APC: No timezone found, symbol may be delisted
# - TIF: No timezone found, symbol may be delisted
# - AGN: No timezone found, symbol may be delisted
# - ARNC: Data doesn't exist for startDate = 1448946000, endDate = 1577768400
# - RHT: No timezone found, symbol may be delisted
# - DRE: No timezone found, symbol may be delisted
# - STI: No timezone found, symbol may be delisted
# - 2018: No timezone found, symbol may be delisted
# - INFO: No timezone found, symbol may be delisted
# - SIVB: No timezone found, symbol may be delisted
# - ADS: No timezone found, symbol may be delisted
# - FLIR: No timezone found, symbol may be delisted
# (36, 460)
# GE     -0.438881
# PRGO   -0.431025
# COTY   -0.426021
# BBWI   -0.380294
# MAT    -0.303762
# DISH   -0.276176
# NWL    -0.262850
# HBI    -0.258392
# PCG    -0.247765
# VTRS   -0.226579
# dtype: float64
# ['GE', 'PRGO', 'COTY', 'BBWI', 'MAT', 'DISH', 'NWL', 'HBI', 'PCG', 'VTRS']
# 0.15940032978101673
# [-0.14769898692233838, 0.3996787968108296, -0.04495962534446742, 0.15940032978101673]
# ['2017', 'MMM', 'AOS', 'ABT', 'ABBV', 'ACN', 'ATVI', 'ADM', 'ADBE', 'ADP', 'AAP', 'AES', 'AFL', 'A', 'APD', 'AKAM', 'ALK', 'ALB', 'ARE', 'ALGN', 'ALLE', 'LNT', 'ALL', 'GOOGL', 'GOOG', 'MO', 'AMZN', 'MAT', 'AMD', 'AEE', 'AAL', 'AEP', 'AXP', 'AIG', 'AMT', 'AWK', 'AMP', 'ABC', 'AME', 'AMGN', 'APH', 'ADI', 'ANSS', 'AON', 'APA', 'AAPL', 'AMAT', 'APTV', 'MON', 'GGP', 'AJG', 'AIZ', 'T', 'NFX', 'ADSK', 'AZO', 'AVB', 'AVY', 'SCG', 'BKR', 'BALL', 'BAC', 'BBWI', 'BAX', 'BDX', 'VIAB', 'BRK-B', 'BBY', 'ADS', 'AET', 'BIIB', 'BLK', 'BK', 'BA', 'BKNG', 'BWA', 'BXP', 'BSX', 'BMY', 'AVGO', 'RRC', 'NOV', 'BF-B', 'LEG', 'CHRW', 'CDNS', 'NBL', 'PBCT', 'CPB', 'COF', 'CAH', 'KMX', 'CCL', 'RTN', 'KSS', 'CAT', 'CBOE', 'CBRE', 'TSS', 'ESRX', 'CNC', 'CNP', 'UNM', 'CF', 'FLIR', 'SCHW', 'CHTR', 'CVX', 'CMG', 'CB', 'CHD', 'CI', 'CINF', 'CTAS', 'CSCO', 'C', 'CFG', 'CLX', 'CME', 'CMS', 'KO', 'CTSH', 'CL', 'CMCSA', 'CMA', 'CAG', 'COP', 'ED', 'STZ', 'GPS', 'COO', 'DPS', 'GLW', 'FLR', 'PVH', 'COST', 'CTRA', 'CCI', 'CSX', 'CMI', 'CVS', 'DHI', 'DHR', 'DRI', 'DVA', 'DE', 'DAL', 'XRAY', 'DVN', 'AGN', 'SRCL', 'DLR', 'DFS', 'DISH', 'DIS', 'DG', 'DLTR', 'D', 'CPRI', 'DOV', 'BHF', 'DTE', 'DUK', 'DWDP', 'DXC', 'EMN', 'ETN', 'EBAY', 'ECL', 'EIX', 'EW', 'EA', 'ELV', 'LLY', 'EMR', 'TIF', 'ETR', 'EOG', 'KSU', 'DRE', 'EFX', 'EQIX', 'EQR', 'ESS', 'EL', 'HRB', 'RE', 'NAVI', 'ES', 'EXC', 'EXPE', 'EXPD', 'EXR', 'XOM', 'FFIV', 'WU', 'LUMN', 'FAST', 'FRT', 'FDX', 'FITB', 'FBHS', 'FE', 'FIS', 'FISV', 'TWX', 'FMC', 'F', 'EVHC', 'FTV', 'FOXA', 'FOX', 'BEN', 'FCX', 'GRMN', 'IT', 'VNO', 'GEN', 'XRX', 'GD', 'GE', 'GIS', 'GM', 'GPC', 'GILD', 'GL', 'GPN', 'GS', 'HAL', 'HIG', 'HAS', 'HCA', 'PEAK', 'HSIC', 'HSY', 'HES', 'HPE', 'HLT', 'HOLX', 'HD', 'HON', 'HRL', 'HST', 'ARNC', 'HPQ', 'HUM', 'HBAN', 'BCR', 'IBM', 'FL', 'IDXX', 'ITW', 'ILMN', 'INCY', 'XEC', 'PDCO', 'INTC', 'ICE', 'IFF', 'IP', 'IPG', 'INTU', 'ISRG', 'IVZ', 'SLG', 'IQV', 'IRM', 'JBHT', 'EQT', 'J', 'JNJ', 'JCI', 'JPM', 'JNPR', 'K', 'UA', 'KEY', 'CA', 'KMB', 'KIM', 'KMI', 'KLAC', 'KHC', 'KR', 'LHX', 'LH', 'LRCX', 'COL', 'CHK', 'APC', 'LEN', 'LNC', 'LIN', 'AMG', 'LKQ', 'LMT', 'L', 'LOW', 'LYB', 'MTB', 'MRO', 'MPC', 'LLL', 'MAR', 'MMC', 'MLM', 'MAS', 'MA', 'PRGO', 'MKC', 'MCD', 'MCK', 'MDT', 'MRK', 'META', 'MET', 'MTD', 'MGM', 'MCHP', 'MU', 'MSFT', 'MAA', 'ALXN', 'MHK', 'INFO', 'TAP', 'MDLZ', 'FTI', 'MNST', 'MCO', 'MS', 'MOS', 'MSI', 'CSRA', 'NDAQ', 'NTAP', 'NFLX', 'NWL', 'NEM', 'NWSA', 'NWS', 'NEE', 'NKE', 'NI', 'XLNX', 'NSC', 'NTRS', 'NOC', 'NCLH', 'NRG', 'NUE', 'NVDA', 'JEF', 'FLS', 'ORLY', 'OXY', 'STI', 'OMC', 'SNI', 'OKE', 'ORCL', 'AYI', 'M', 'PCAR', 'PKG', 'PARA', 'PH', 'PAYX', 'XL', 'PYPL', 'PNR', 'PEP', 'PFE', 'CTXS', 'PM', 'PSX', 'PNW', 'PXD', 'PNC', 'ETFC', 'PPG', 'PPL', 'PFG', 'PG', 'PGR', 'PLD', 'PRU', 'PEG', 'VAR', 'PSA', 'PHM', 'QRVO', 'PWR', 'QCOM', 'DGX', 'RL', 'RJF', 'RTX', 'O', 'REG', 'REGN', 'RF', 'RSG', 'RMD', 'RVTY', 'RHI', 'ROK', 'ANDV', 'ROP', 'ROST', 'RCL', 'SPGI', 'CRM', 'SBAC', 'SLB', 'STX', 'SEE', 'SRE', 'CELG', 'SHW', 'SPG', 'SWKS', 'SJM', 'SNA', 'HBI', 'SO', 'LUV', 'SWK', 'SBUX', 'STT', 'WYN', 'MAC', 'SYK', 'SYF', 'SNPS', 'SYY', 'RHT', 'TROW', 'SIG', 'TPR', 'NLSN', 'TGT', 'TEL', 'HOG', 'PCG', 'COTY', 'AIV', 'TXN', 'TXT', 'TMO', 'TJX', 'TSCO', 'TT', 'TDG', 'TRV', 'CXO', 'TFC', 'JWN', 'TSN', 'USB', 'UDR', 'ULTA', 'UNP', 'UAL', 'UPS', 'URI', 'UNH', 'UHS', 'VLO', 'VTR', 'VRSN', 'VRSK', 'VZ', 'VRTX', 'VFC', 'VTRS', 'CERN', 'V', 'VMC', 'GT', 'WBA', 'WMT', 'WBD', 'WM', 'WAT', 'WEC', 'WFC', 'WELL', 'HP', 'WDC', 'WRK', 'WY', 'WHR', 'WMB', 'WTW', 'GWW', 'WYNN', 'XEL', 'XYL', 'YUM', 'TRIP', 'ZBH', 'ZION', 'ZTS']
#
# 40 Failed downloads:
# - ETFC: No timezone found, symbol may be delisted
# - KSU: No timezone found, symbol may be delisted
# - GGP: No data found for this date range, symbol may be delisted
# - XEC: No timezone found, symbol may be delisted
# - VIAB: No timezone found, symbol may be delisted
# - NLSN: No timezone found, symbol may be delisted
# - FOX: Data doesn't exist for startDate = 1417410000, endDate = 1546232400
# - WYN: No data found for this date range, symbol may be delisted
# - CERN: No timezone found, symbol may be delisted
# - FISV: Data doesn't exist for startDate = 1417410000, endDate = 1546232400
# - FBHS: No timezone found, symbol may be delisted
# - CELG: No timezone found, symbol may be delisted
# - XLNX: No timezone found, symbol may be delisted
# - FOXA: Data doesn't exist for startDate = 1417410000, endDate = 1546232400
# - DPS: No data found for this date range, symbol may be delisted
# - LLL: No timezone found, symbol may be delisted
# - ALXN: No timezone found, symbol may be delisted
# - VAR: No timezone found, symbol may be delisted
# - MON: No timezone found, symbol may be delisted
# - RTN: No timezone found, symbol may be delisted
# - DWDP: No timezone found, symbol may be delisted
# - XL: No timezone found, symbol may be delisted
# - BCR: No data found for this date range, symbol may be delisted
# - NBL: No timezone found, symbol may be delisted
# - TSS: No timezone found, symbol may be delisted
# - CXO: No timezone found, symbol may be delisted
# - PBCT: No timezone found, symbol may be delisted
# - CTXS: No timezone found, symbol may be delisted
# - APC: No timezone found, symbol may be delisted
# - TIF: No timezone found, symbol may be delisted
# - 2017: No timezone found, symbol may be delisted
# - AGN: No timezone found, symbol may be delisted
# - ARNC: Data doesn't exist for startDate = 1417410000, endDate = 1546232400
# - RHT: No timezone found, symbol may be delisted
# - DRE: No timezone found, symbol may be delisted
# - STI: No timezone found, symbol may be delisted
# - INFO: No timezone found, symbol may be delisted
# - CHK: Data doesn't exist for startDate = 1417410000, endDate = 1546232400
# - ADS: No timezone found, symbol may be delisted
# - FLIR: No timezone found, symbol may be delisted
# C:\Users\Philip\anaconda3\lib\site-packages\pandas\core\internals\blocks.py:351: RuntimeWarning: invalid value encountered in log
#   result = func(self.values, **kwargs)
# (36, 452)
# RRC    -0.377367
# LUMN   -0.288038
# CMG    -0.287391
# M      -0.281005
# SIG    -0.268821
# TRIP   -0.257715
# KMI    -0.247963
# SRCL   -0.218816
# PRGO   -0.210599
# MAT    -0.182971
# dtype: float64
# ['RRC', 'LUMN', 'CMG', 'M', 'SIG', 'TRIP', 'KMI', 'SRCL', 'PRGO', 'MAT']
# -0.11921808577143563
# [-0.14769898692233838, 0.3996787968108296, -0.04495962534446742, 0.15940032978101673, -0.11921808577143563]
# ['2016', 'MMM', 'BBBY', 'ABT', 'ABBV', 'ACN', 'ATVI', 'ADM', 'ADBE', 'ADP', 'AAP', 'AES', 'AFL', 'A', 'APD', 'AKAM', 'ALK', 'ALB', 'FSLR', 'TDC', 'ALLE', 'LNT', 'ALL', 'GOOGL', 'GOOG', 'MO', 'AMZN', 'MAT', 'URBN', 'AEE', 'AAL', 'AEP', 'AXP', 'AIG', 'AMT', 'AWK', 'AMP', 'ABC', 'AME', 'AMGN', 'APH', 'ADI', 'R', 'AON', 'APA', 'AAPL', 'AMAT', 'APTV', 'MON', 'GGP', 'AJG', 'AIZ', 'T', 'NFX', 'ADSK', 'AZO', 'AVB', 'AVY', 'SCG', 'BKR', 'BALL', 'BAC', 'BBWI', 'BAX', 'BDX', 'VIAB', 'BRK-B', 'BBY', 'ADS', 'AET', 'BIIB', 'BLK', 'BK', 'BA', 'BKNG', 'BWA', 'BXP', 'BSX', 'BMY', 'AVGO', 'RRC', 'NOV', 'BF-B', 'LEG', 'CHRW', 'SPLS', 'NBL', 'PBCT', 'CPB', 'COF', 'CAH', 'KMX', 'CCL', 'RTN', 'KSS', 'CAT', 'PBI', 'CBRE', 'TSS', 'ESRX', 'CNC', 'CNP', 'UNM', 'CF', 'FLIR', 'SCHW', 'CHTR', 'CVX', 'CMG', 'CB', 'CHD', 'CI', 'CINF', 'CTAS', 'CSCO', 'C', 'CFG', 'CLX', 'CME', 'CMS', 'KO', 'CTSH', 'CL', 'CMCSA', 'CMA', 'CAG', 'COP', 'ED', 'STZ', 'GPS', 'COO', 'DPS', 'GLW', 'FLR', 'PVH', 'COST', 'CTRA', 'CCI', 'CSX', 'CMI', 'CVS', 'DHI', 'DHR', 'DRI', 'DVA', 'DE', 'DAL', 'XRAY', 'DVN', 'AGN', 'SRCL', 'DLR', 'DFS', 'LLTC', 'DIS', 'DG', 'DLTR', 'D', 'CPRI', 'DOV', 'AN', 'DTE', 'DUK', 'DOW', 'SWN', 'EMN', 'ETN', 'EBAY', 'ECL', 'EIX', 'EW', 'EA', 'ELV', 'LLY', 'EMR', 'TIF', 'ETR', 'EOG', 'KSU', 'RIG', 'EFX', 'EQIX', 'EQR', 'ESS', 'EL', 'HRB', 'MJN', 'NAVI', 'ES', 'EXC', 'EXPE', 'EXPD', 'EXR', 'XOM', 'FFIV', 'WU', 'LUMN', 'FAST', 'FRT', 'FDX', 'FITB', 'FBHS', 'FE', 'FIS', 'FISV', 'TWX', 'FMC', 'F', 'EVHC', 'FTV', 'FOXA', 'FOX', 'BEN', 'FCX', 'GRMN', 'DNB', 'VNO', 'GEN', 'XRX', 'GD', 'GE', 'GIS', 'GM', 'GPC', 'GILD', 'GL', 'GPN', 'GS', 'HAL', 'HIG', 'HAS', 'HCA', 'PEAK', 'HSIC', 'HSY', 'HES', 'HPE', 'YHOO', 'HOLX', 'HD', 'HON', 'HRL', 'HST', 'ARNC', 'HPQ', 'HUM', 'HBAN', 'BCR', 'IBM', 'FL', 'STJ', 'ITW', 'ILMN', 'SE', 'XEC', 'PDCO', 'INTC', 'ICE', 'IFF', 'IP', 'IPG', 'INTU', 'ISRG', 'IVZ', 'SLG', 'IQV', 'IRM', 'JBHT', 'EQT', 'J', 'JNJ', 'JCI', 'JPM', 'JNPR', 'K', 'UA', 'KEY', 'CA', 'KMB', 'KIM', 'KMI', 'KLAC', 'KHC', 'KR', 'LHX', 'LH', 'LRCX', 'COL', 'CHK', 'APC', 'LEN', 'LNC', 'LIN', 'AMG', 'LKQ', 'LMT', 'L', 'LOW', 'LYB', 'MTB', 'MRO', 'MPC', 'LLL', 'MAR', 'MMC', 'MLM', 'MAS', 'MA', 'PRGO', 'MKC', 'MCD', 'MCK', 'MDT', 'MRK', 'META', 'MET', 'MTD', 'RAI', 'MCHP', 'MU', 'MSFT', 'MAA', 'ALXN', 'MHK', 'TGNA', 'TAP', 'MDLZ', 'FTI', 'MNST', 'MCO', 'MS', 'MOS', 'MSI', 'CSRA', 'NDAQ', 'NTAP', 'NFLX', 'NWL', 'NEM', 'NWSA', 'NWS', 'NEE', 'NKE', 'NI', 'XLNX', 'NSC', 'NTRS', 'NOC', 'LVLT', 'NRG', 'NUE', 'NVDA', 'JEF', 'FLS', 'ORLY', 'OXY', 'STI', 'OMC', 'SNI', 'OKE', 'ORCL', 'AYI', 'M', 'PCAR', 'MUR', 'PARA', 'PH', 'PAYX', 'XL', 'PYPL', 'PNR', 'PEP', 'PFE', 'CTXS', 'PM', 'PSX', 'PNW', 'PXD', 'PNC', 'ETFC', 'PPG', 'PPL', 'PFG', 'PG', 'PGR', 'PLD', 'PRU', 'PEG', 'VAR', 'PSA', 'PHM', 'QRVO', 'PWR', 'QCOM', 'DGX', 'RL', 'FTR', 'RTX', 'O', 'ENDP', 'REGN', 'RF', 'RSG', 'MNK', 'RVTY', 'RHI', 'ROK', 'ANDV', 'ROP', 'ROST', 'RCL', 'SPGI', 'CRM', 'DD', 'SLB', 'STX', 'SEE', 'SRE', 'CELG', 'SHW', 'SPG', 'SWKS', 'SJM', 'SNA', 'HBI', 'SO', 'LUV', 'SWK', 'SBUX', 'STT', 'WYN', 'MAC', 'SYK', 'SYF', 'HAR', 'SYY', 'RHT', 'TROW', 'SIG', 'TPR', 'NLSN', 'TGT', 'TEL', 'HOG', 'PCG', 'COTY', 'AIV', 'TXN', 'TXT', 'TMO', 'TJX', 'TSCO', 'TT', 'TDG', 'TRV', 'CXO', 'TFC', 'JWN', 'TSN', 'USB', 'UDR', 'ULTA', 'UNP', 'UAL', 'UPS', 'URI', 'UNH', 'UHS', 'VLO', 'VTR', 'VRSN', 'VRSK', 'VZ', 'VRTX', 'VFC', 'VTRS', 'CERN', 'V', 'VMC', 'GT', 'WBA', 'WMT', 'WBD', 'WM', 'WAT', 'WEC', 'WFC', 'WELL', 'HP', 'WDC', 'WRK', 'WY', 'WHR', 'WMB', 'WTW', 'GWW', 'WYNN', 'XEL', 'XYL', 'YUM', 'TRIP', 'ZBH', 'ZION', 'ZTS', 'WFM']
#
# 51 Failed downloads:
# - ETFC: No timezone found, symbol may be delisted
# - LLTC: No data found for this date range, symbol may be delisted
# - KSU: No timezone found, symbol may be delisted
# - ENDP: No timezone found, symbol may be delisted
# - GGP: No data found for this date range, symbol may be delisted
# - XEC: No timezone found, symbol may be delisted
# - VIAB: No timezone found, symbol may be delisted
# - NLSN: No timezone found, symbol may be delisted
# - FOX: Data doesn't exist for startDate = 1385874000, endDate = 1514696400
# - WYN: No data found for this date range, symbol may be delisted
# - SPLS: No data found for this date range, symbol may be delisted
# - FTR: No timezone found, symbol may be delisted
# - MJN: No data found for this date range, symbol may be delisted
# - CERN: No timezone found, symbol may be delisted
# - FISV: Data doesn't exist for startDate = 1385874000, endDate = 1514696400
# - FBHS: No timezone found, symbol may be delisted
# - CELG: No timezone found, symbol may be delisted
# - RAI: No data found for this date range, symbol may be delisted
# - XLNX: No timezone found, symbol may be delisted
# - LVLT: No data found for this date range, symbol may be delisted
# - FOXA: Data doesn't exist for startDate = 1385874000, endDate = 1514696400
# - DPS: No data found for this date range, symbol may be delisted
# - LLL: No timezone found, symbol may be delisted
# - VAR: No timezone found, symbol may be delisted
# - ALXN: No timezone found, symbol may be delisted
# - MON: No timezone found, symbol may be delisted
# - RTN: No timezone found, symbol may be delisted
# - YHOO: No data found for this date range, symbol may be delisted
# - DNB: Data doesn't exist for startDate = 1385874000, endDate = 1514696400
# - XL: No timezone found, symbol may be delisted
# - BCR: No data found for this date range, symbol may be delisted
# - NBL: No timezone found, symbol may be delisted
# - TSS: No timezone found, symbol may be delisted
# - CXO: No timezone found, symbol may be delisted
# - DOW: Data doesn't exist for startDate = 1385874000, endDate = 1514696400
# - 2016: No timezone found, symbol may be delisted
# - HAR: No data found for this date range, symbol may be delisted
# - WFM: No data found for this date range, symbol may be delisted
# - PBCT: No timezone found, symbol may be delisted
# - CTXS: No timezone found, symbol may be delisted
# - STJ: No data found for this date range, symbol may be delisted
# - APC: No timezone found, symbol may be delisted
# - TIF: No timezone found, symbol may be delisted
# - AGN: No timezone found, symbol may be delisted
# - ARNC: Data doesn't exist for startDate = 1385874000, endDate = 1514696400
# - RHT: No timezone found, symbol may be delisted
# - STI: No timezone found, symbol may be delisted
# - CHK: Data doesn't exist for startDate = 1385874000, endDate = 1514696400
# - MNK: Data doesn't exist for startDate = 1385874000, endDate = 1514696400
# - ADS: No timezone found, symbol may be delisted
# - FLIR: No timezone found, symbol may be delisted
# C:\Users\Philip\anaconda3\lib\site-packages\pandas\core\internals\blocks.py:351: RuntimeWarning: invalid value encountered in log
#   result = func(self.values, **kwargs)
# (36, 439)
# SWN    -0.430197
# RIG    -0.358089
# FCX    -0.329338
# RRC    -0.296331
# NRG    -0.260693
# WYNN   -0.242586
# BBBY   -0.225067
# MRO    -0.213900
# CPRI   -0.212019
# RL     -0.208155
# dtype: float64
# ['SWN', 'RIG', 'FCX', 'RRC', 'NRG', 'WYNN', 'BBBY', 'MRO', 'CPRI', 'RL']
# 0.15515753777816654
# [-0.14769898692233838, 0.3996787968108296, -0.04495962534446742, 0.15940032978101673, -0.11921808577143563, 0.15515753777816654]
# ['2015', 'MMM', 'BBBY', 'ABT', 'ABBV', 'ACN', 'ATVI', 'ADM', 'ADBE', 'ADP', 'AAP', 'AES', 'AFL', 'A', 'APD', 'AKAM', 'SNDK', 'TE', 'FSLR', 'TDC', 'ALLE', 'GAS', 'ALL', 'GOOGL', 'GOOG', 'MO', 'AMZN', 'MAT', 'URBN', 'AEE', 'AAL', 'AEP', 'AXP', 'AIG', 'AMT', 'CNX', 'AMP', 'ABC', 'AME', 'AMGN', 'APH', 'ADI', 'R', 'AON', 'APA', 'AAPL', 'AMAT', 'APTV', 'MON', 'GGP', 'CCE', 'AIZ', 'T', 'NFX', 'ADSK', 'AZO', 'AVB', 'AVY', 'SCG', 'BKR', 'BALL', 'BAC', 'BBWI', 'BAX', 'BDX', 'VIAB', 'BRK-B', 'BBY', 'ADS', 'AET', 'BIIB', 'BLK', 'BK', 'BA', 'BKNG', 'BWA', 'BXP', 'BSX', 'BMY', 'AVGO', 'RRC', 'NOV', 'BF-B', 'LEG', 'CHRW', 'SPLS', 'NBL', 'PBCT', 'CPB', 'COF', 'CAH', 'KMX', 'CCL', 'RTN', 'KSS', 'CAT', 'PBI', 'CBRE', 'TSS', 'ESRX', 'ESV', 'CNP', 'UNM', 'CF', 'FLIR', 'SCHW', 'EMC', 'CVX', 'CMG', 'CB', 'CHD', 'CI', 'CINF', 'CTAS', 'CSCO', 'C', 'PCP', 'CLX', 'CME', 'CMS', 'KO', 'CTSH', 'CL', 'CMCSA', 'CMA', 'CAG', 'COP', 'ED', 'STZ', 'GPS', 'HOT', 'DPS', 'GLW', 'FLR', 'PVH', 'COST', 'CTRA', 'CCI', 'CSX', 'CMI', 'CVS', 'DHI', 'DHR', 'DRI', 'DVA', 'DE', 'DAL', 'XRAY', 'DVN', 'AGN', 'SRCL', 'TWC', 'DFS', 'LLTC', 'DIS', 'DG', 'DLTR', 'D', 'CPRI', 'DOV', 'AN', 'DTE', 'DUK', 'DOW', 'SWN', 'EMN', 'ETN', 'EBAY', 'ECL', 'EIX', 'EW', 'EA', 'ELV', 'LLY', 'EMR', 'TIF', 'ETR', 'EOG', 'KSU', 'RIG', 'EFX', 'EQIX', 'EQR', 'ESS', 'EL', 'HRB', 'MJN', 'NAVI', 'ES', 'EXC', 'EXPE', 'EXPD', 'ACE', 'XOM', 'FFIV', 'WU', 'LUMN', 'FAST', 'BRCM', 'FDX', 'FITB', 'CVC', 'FE', 'FIS', 'FISV', 'TWX', 'FMC', 'F', 'LM', 'CPGX', 'FOXA', 'FOX', 'BEN', 'FCX', 'GRMN', 'DNB', 'VNO', 'GEN', 'XRX', 'GD', 'GE', 'GIS', 'GM', 'GPC', 'GILD', 'GL', 'GME', 'GS', 'HAL', 'HIG', 'HAS', 'HCA', 'PEAK', 'HSIC', 'HSY', 'HES', 'HPE', 'YHOO', 'POM', 'HD', 'HON', 'HRL', 'HST', 'AA', 'HPQ', 'HUM', 'HBAN', 'BCR', 'IBM', 'CAM', 'STJ', 'ITW', 'ILMN', 'SE', 'XEC', 'PDCO', 'INTC', 'ICE', 'IFF', 'IP', 'IPG', 'INTU', 'ISRG', 'IVZ', 'SLG', 'IQV', 'IRM', 'JBHT', 'EQT', 'J', 'JNJ', 'JCI', 'JPM', 'JNPR', 'K', 'UA', 'KEY', 'CA', 'KMB', 'KIM', 'KMI', 'KLAC', 'KHC', 'KR', 'LHX', 'LH', 'LRCX', 'COL', 'CHK', 'APC', 'LEN', 'LNC', 'LIN', 'AMG', 'ARG', 'LMT', 'L', 'LOW', 'LYB', 'MTB', 'MRO', 'MPC', 'LLL', 'MAR', 'MMC', 'MLM', 'MAS', 'MA', 'PRGO', 'MKC', 'MCD', 'MCK', 'MDT', 'MRK', 'META', 'MET', 'TYC', 'RAI', 'MCHP', 'MU', 'MSFT', 'OI', 'ALXN', 'MHK', 'TGNA', 'TAP', 'MDLZ', 'FTI', 'MNST', 'MCO', 'MS', 'MOS', 'MSI', 'CSRA', 'NDAQ', 'NTAP', 'NFLX', 'NWL', 'NEM', 'NWSA', 'NWS', 'NEE', 'NKE', 'NI', 'XLNX', 'NSC', 'NTRS', 'NOC', 'LVLT', 'NRG', 'NUE', 'NVDA', 'JEF', 'FLS', 'ORLY', 'OXY', 'STI', 'OMC', 'SNI', 'OKE', 'ORCL', 'ADT', 'M', 'PCAR', 'MUR', 'PARA', 'PH', 'PAYX', 'XL', 'PYPL', 'PNR', 'PEP', 'PFE', 'CTXS', 'PM', 'PSX', 'PNW', 'PXD', 'PNC', 'ETFC', 'PPG', 'PPL', 'PFG', 'PG', 'PGR', 'PLD', 'PRU', 'PEG', 'VAR', 'PSA', 'PHM', 'QRVO', 'PWR', 'QCOM', 'DGX', 'RL', 'FTR', 'RTX', 'O', 'ENDP', 'REGN', 'RF', 'RSG', 'MNK', 'RVTY', 'RHI', 'ROK', 'ANDV', 'ROP', 'ROST', 'RCL', 'SPGI', 'CRM', 'DD', 'SLB', 'STX', 'SEE', 'SRE', 'CELG', 'SHW', 'SPG', 'SWKS', 'SJM', 'SNA', 'HBI', 'SO', 'LUV', 'SWK', 'SBUX', 'STT', 'WYN', 'MAC', 'SYK', 'SYF', 'HAR', 'SYY', 'RHT', 'TROW', 'SIG', 'TPR', 'NLSN', 'TGT', 'TEL', 'HOG', 'PCG', 'DO', 'AIV', 'TXN', 'TXT', 'TMO', 'TJX', 'TSCO', 'TT', 'BXLT', 'TRV', 'PCL', 'TFC', 'JWN', 'TSN', 'USB', 'GMCR', 'THC', 'UNP', 'UAL', 'UPS', 'URI', 'UNH', 'UHS', 'VLO', 'VTR', 'VRSN', 'VRSK', 'VZ', 'VRTX', 'VFC', 'VTRS', 'CERN', 'V', 'VMC', 'GT', 'WBA', 'WMT', 'WBD', 'WM', 'WAT', 'WEC', 'WFC', 'WELL', 'HP', 'WDC', 'WRK', 'WY', 'WHR', 'WMB', 'FOSL', 'GWW', 'WYNN', 'XEL', 'XYL', 'YUM', 'TRIP', 'ZBH', 'ZION', 'ZTS', 'WFM']
#
# 71 Failed downloads:
# - SNDK: No data found for this date range, symbol may be delisted
# - ETFC: No timezone found, symbol may be delisted
# - LLTC: No data found for this date range, symbol may be delisted
# - KSU: No timezone found, symbol may be delisted
# - ENDP: No timezone found, symbol may be delisted
# - GGP: No data found for this date range, symbol may be delisted
# - PCL: No data found for this date range, symbol may be delisted
# - SE: Data doesn't exist for startDate = 1354338000, endDate = 1483160400
# - XEC: No timezone found, symbol may be delisted
# - VIAB: No timezone found, symbol may be delisted
# - GAS: No data found for this date range, symbol may be delisted
# - ARG: Data doesn't exist for startDate = 1354338000, endDate = 1483160400
# - NLSN: No timezone found, symbol may be delisted
# - ADT: Data doesn't exist for startDate = 1354338000, endDate = 1483160400
# - FOX: Data doesn't exist for startDate = 1354338000, endDate = 1483160400
# - WYN: No data found for this date range, symbol may be delisted
# - SPLS: No data found for this date range, symbol may be delisted
# - ESV: No timezone found, symbol may be delisted
# - FTR: No timezone found, symbol may be delisted
# - MJN: No data found for this date range, symbol may be delisted
# - CERN: No timezone found, symbol may be delisted
# - LM: No timezone found, symbol may be delisted
# - FISV: Data doesn't exist for startDate = 1354338000, endDate = 1483160400
# - CELG: No timezone found, symbol may be delisted
# - BRCM: No data found for this date range, symbol may be delisted
# - TYC: No data found for this date range, symbol may be delisted
# - RAI: No data found for this date range, symbol may be delisted
# - ACE: Data doesn't exist for startDate = 1354338000, endDate = 1483160400
# - XLNX: No timezone found, symbol may be delisted
# - BXLT: No data found for this date range, symbol may be delisted
# - LVLT: No data found for this date range, symbol may be delisted
# - CVC: No data found for this date range, symbol may be delisted
# - FOXA: Data doesn't exist for startDate = 1354338000, endDate = 1483160400
# - DPS: No data found for this date range, symbol may be delisted
# - TE: No data found for this date range, symbol may be delisted
# - EMC: Data doesn't exist for startDate = 1354338000, endDate = 1483160400
# - LLL: No timezone found, symbol may be delisted
# - ALXN: No timezone found, symbol may be delisted
# - VAR: No timezone found, symbol may be delisted
# - MON: No timezone found, symbol may be delisted
# - 2015: No timezone found, symbol may be delisted
# - GMCR: No data found for this date range, symbol may be delisted
# - RTN: No timezone found, symbol may be delisted
# - YHOO: No data found for this date range, symbol may be delisted
# - DNB: Data doesn't exist for startDate = 1354338000, endDate = 1483160400
# - XL: No timezone found, symbol may be delisted
# - BCR: No data found for this date range, symbol may be delisted
# - NBL: No timezone found, symbol may be delisted
# - TSS: No timezone found, symbol may be delisted
# - DOW: Data doesn't exist for startDate = 1354338000, endDate = 1483160400
# - DO: Data doesn't exist for startDate = 1354338000, endDate = 1483160400
# - CAM: No data found for this date range, symbol may be delisted
# - POM: No data found for this date range, symbol may be delisted
# - HAR: No data found for this date range, symbol may be delisted
# - WFM: No data found for this date range, symbol may be delisted
# - PBCT: No timezone found, symbol may be delisted
# - CTXS: No timezone found, symbol may be delisted
# - STJ: No data found for this date range, symbol may be delisted
# - APC: No timezone found, symbol may be delisted
# - TIF: No timezone found, symbol may be delisted
# - PCP: Data doesn't exist for startDate = 1354338000, endDate = 1483160400
# - TWC: No data found for this date range, symbol may be delisted
# - AGN: No timezone found, symbol may be delisted
# - RHT: No timezone found, symbol may be delisted
# - CCE: No data found for this date range, symbol may be delisted
# - STI: No timezone found, symbol may be delisted
# - CHK: Data doesn't exist for startDate = 1354338000, endDate = 1483160400
# - MNK: Data doesn't exist for startDate = 1354338000, endDate = 1483160400
# - ADS: No timezone found, symbol may be delisted
# - CPGX: No data found for this date range, symbol may be delisted
# - FLIR: No timezone found, symbol may be delisted
# C:\Users\Philip\anaconda3\lib\site-packages\pandas\core\internals\blocks.py:351: RuntimeWarning: invalid value encountered in log
#   result = func(self.values, **kwargs)
# (36, 416)
# SWN    -0.515784
# FCX    -0.491024
# CNX    -0.458371
# RIG    -0.371483
# FOSL   -0.311573
# RRC    -0.309897
# NEM    -0.296620
# TDC    -0.283746
# MRO    -0.272197
# MUR    -0.249645
# dtype: float64
# ['SWN', 'FCX', 'CNX', 'RIG', 'FOSL', 'RRC', 'NEM', 'TDC', 'MRO', 'MUR']
# 0.39659759277471024
# [-0.14769898692233838, 0.3996787968108296, -0.04495962534446742, 0.15940032978101673, -0.11921808577143563, 0.15515753777816654, 0.39659759277471024]
# ['2014', 'MMM', 'BBBY', 'ABT', 'ABBV', 'ACN', 'PLL', 'ADM', 'ADBE', 'ADP', 'FDO', 'AES', 'AFL', 'A', 'APD', 'AKAM', 'SNDK', 'TE', 'FSLR', 'TDC', 'ALLE', 'GAS', 'ALL', 'GOOGL', 'GOOG', 'MO', 'AMZN', 'MAT', 'URBN', 'AEE', 'AGN', 'AEP', 'AXP', 'AIG', 'AMT', 'CNX', 'AMP', 'ABC', 'AME', 'AMGN', 'APH', 'ADI', 'R', 'AON', 'APA', 'AAPL', 'AMAT', 'APTV', 'MON', 'GGP', 'CCE', 'AIZ', 'T', 'NFX', 'ADSK', 'AZO', 'AVB', 'AVY', 'SCG', 'BKR', 'BALL', 'BAC', 'BBWI', 'BAX', 'BDX', 'VIAB', 'BRK-B', 'BBY', 'ADS', 'AET', 'BIIB', 'BLK', 'BK', 'BA', 'BKNG', 'BWA', 'BXP', 'BSX', 'BMY', 'AVGO', 'RRC', 'NOV', 'BF-B', 'LEG', 'CHRW', 'SPLS', 'NBL', 'PBCT', 'CPB', 'COF', 'CAH', 'KMX', 'CCL', 'RTN', 'KSS', 'CAT', 'PBI', 'CBRE', 'TSS', 'ESRX', 'ESV', 'CNP', 'UNM', 'CF', 'FLIR', 'SCHW', 'EMC', 'CVX', 'CMG', 'CB', 'ALTR', 'CI', 'CINF', 'CTAS', 'CSCO', 'C', 'PCP', 'CLX', 'CME', 'CMS', 'KO', 'CTSH', 'CL', 'CMCSA', 'CMA', 'CAG', 'COP', 'ED', 'STZ', 'GPS', 'HOT', 'DPS', 'GLW', 'FLR', 'PVH', 'COST', 'CTRA', 'CCI', 'CSX', 'CMI', 'CVS', 'DHI', 'DHR', 'DRI', 'DVA', 'DE', 'DAL', 'XRAY', 'DVN', 'AGN', 'SRCL', 'TWC', 'DFS', 'LLTC', 'DIS', 'DG', 'DLTR', 'D', 'CPRI', 'DOV', 'AN', 'DTE', 'DUK', 'DOW', 'SWN', 'EMN', 'ETN', 'EBAY', 'ECL', 'EIX', 'EW', 'EA', 'ELV', 'LLY', 'EMR', 'TIF', 'ETR', 'EOG', 'KSU', 'RIG', 'EFX', 'DNR', 'EQR', 'ESS', 'EL', 'HRB', 'MJN', 'NAVI', 'ES', 'EXC', 'EXPE', 'EXPD', 'ACE', 'XOM', 'FFIV', 'WU', 'LUMN', 'FAST', 'BRCM', 'FDX', 'FITB', 'CVC', 'FE', 'FIS', 'FISV', 'TWX', 'FMC', 'F', 'LM', 'ATI', 'FOXA', 'BEN', 'FCX', 'GRMN', 'DNB', 'VNO', 'GEN', 'XRX', 'GD', 'GE', 'GIS', 'GM', 'GPC', 'GILD', 'GL', 'GME', 'GS', 'HAL', 'HIG', 'HAS', 'SWY', 'PEAK', 'CFN', 'HSY', 'HES', 'HCBK', 'YHOO', 'POM', 'HD', 'HON', 'HRL', 'HST', 'AA', 'HPQ', 'HUM', 'HBAN', 'BCR', 'IBM', 'CAM', 'STJ', 'ITW', 'SIAL', 'SE', 'XEC', 'PDCO', 'INTC', 'ICE', 'IFF', 'IP', 'IPG', 'INTU', 'ISRG', 'IVZ', 'NBR', 'IQV', 'IRM', 'TEG', 'EQT', 'J', 'JNJ', 'JCI', 'JPM', 'JNPR', 'K', 'KEY', 'UA', 'CA', 'KMB', 'KIM', 'KMI', 'KLAC', 'KRFT', 'KR', 'LHX', 'LH', 'LRCX', 'COL', 'CHK', 'APC', 'LEN', 'LNC', 'LIN', 'AMG', 'ARG', 'LMT', 'L', 'LOW', 'LYB', 'MTB', 'MRO', 'MPC', 'LLL', 'MAR', 'MMC', 'MLM', 'MAS', 'MA', 'PRGO', 'MKC', 'MCD', 'MCK', 'MDT', 'MRK', 'META', 'MET', 'TYC', 'RAI', 'MCHP', 'MU', 'MSFT', 'OI', 'ALXN', 'MHK', 'TGNA', 'TAP', 'MDLZ', 'FTI', 'MNST', 'MCO', 'MS', 'MOS', 'MSI', 'CSC', 'NDAQ', 'NTAP', 'NFLX', 'NWL', 'NEM', 'NWSA', 'NEE', 'NKE', 'NI', 'XLNX', 'NSC', 'NTRS', 'NOC', 'LVLT', 'NRG', 'NUE', 'NVDA', 'JEF', 'FLS', 'ORLY', 'OXY', 'STI', 'OMC', 'SNI', 'OKE', 'ORCL', 'ADT', 'M', 'PCAR', 'MUR', 'PARA', 'PH', 'PAYX', 'XL', 'NE', 'PNR', 'PEP', 'PFE', 'CTXS', 'PM', 'PSX', 'PNW', 'PXD', 'PNC', 'ETFC', 'PPG', 'PPL', 'PFG', 'PG', 'PGR', 'PLD', 'PRU', 'PEG', 'VAR', 'PSA', 'PHM', 'LO', 'PWR', 'QCOM', 'DGX', 'RL', 'FTR', 'RTX', 'WIN', 'COV', 'REGN', 'RF', 'RSG', 'MNK', 'RVTY', 'RHI', 'ROK', 'ANDV', 'ROP', 'ROST', 'RCL', 'SPGI', 'CRM', 'DD', 'SLB', 'STX', 'SEE', 'SRE', 'CELG', 'SHW', 'SPG', 'PETM', 'SJM', 'SNA', 'AVP', 'SO', 'LUV', 'SWK', 'SBUX', 'STT', 'WYN', 'MAC', 'SYK', 'GNW', 'HAR', 'SYY', 'RHT', 'TROW', 'DTV', 'TPR', 'NLSN', 'TGT', 'TEL', 'HOG', 'PCG', 'DO', 'AIV', 'TXN', 'TXT', 'TMO', 'TJX', 'TSCO', 'TT', 'QEP', 'TRV', 'PCL', 'TFC', 'JWN', 'TSN', 'USB', 'GMCR', 'THC', 'UNP', 'HSP', 'UPS', 'URI', 'UNH', 'UHS', 'VLO', 'VTR', 'VRSN', 'JOY', 'VZ', 'VRTX', 'VFC', 'VTRS', 'CERN', 'V', 'VMC', 'GT', 'WBA', 'WMT', 'WBD', 'WM', 'WAT', 'WEC', 'WFC', 'WELL', 'HP', 'WDC', 'WRK', 'WY', 'WHR', 'WMB', 'FOSL', 'GWW', 'WYNN', 'XEL', 'XYL', 'YUM', 'TRIP', 'ZBH', 'ZION', 'ZTS', 'WFM']
#
# 89 Failed downloads:
# - SNDK: No data found for this date range, symbol may be delisted
# - HCBK: No data found for this date range, symbol may be delisted
# - ETFC: No timezone found, symbol may be delisted
# - LLTC: No data found for this date range, symbol may be delisted
# - KSU: No timezone found, symbol may be delisted
# - GGP: No data found for this date range, symbol may be delisted
# - PCL: No data found for this date range, symbol may be delisted
# - SE: Data doesn't exist for startDate = 1322715600, endDate = 1451538000
# - VIAB: No timezone found, symbol may be delisted
# - XEC: No timezone found, symbol may be delisted
# - GAS: No data found for this date range, symbol may be delisted
# - ARG: Data doesn't exist for startDate = 1322715600, endDate = 1451538000
# - NLSN: No timezone found, symbol may be delisted
# - ADT: Data doesn't exist for startDate = 1322715600, endDate = 1451538000
# - WYN: No data found for this date range, symbol may be delisted
# - 2014: No timezone found, symbol may be delisted
# - SPLS: No data found for this date range, symbol may be delisted
# - NE: Data doesn't exist for startDate = 1322715600, endDate = 1451538000
# - ESV: No timezone found, symbol may be delisted
# - ALTR: Data doesn't exist for startDate = 1322715600, endDate = 1451538000
# - WIN: No timezone found, symbol may be delisted
# - FTR: No timezone found, symbol may be delisted
# ...
# - JCP: No timezone found, symbol may be delisted
# - WRK: Data doesn't exist for startDate = 1133413200, endDate = 1262235600
# - WFR: No data found for this date range, symbol may be delisted
# - STJ: No data found for this date range, symbol may be delisted
# - APC: No timezone found, symbol may be delisted
# - TIF: No timezone found, symbol may be delisted
# - PCP: Data doesn't exist for startDate = 1133413200, endDate = 1262235600
# - LIFE: Data doesn't exist for startDate = 1133413200, endDate = 1262235600
# - GR: No data found for this date range, symbol may be delisted
# - HNZ: No data found for this date range, symbol may be delisted
# - TWC: No data found for this date range, symbol may be delisted
# - CTX: No data found for this date range, symbol may be delisted
# - MIL: No data found for this date range, symbol may be delisted
# - KG: No data found for this date range, symbol may be delisted
# - AGN: No timezone found, symbol may be delisted
# - RX: No data found for this date range, symbol may be delisted
# - RHT: No timezone found, symbol may be delisted
# - FDO: No data found for this date range, symbol may be delisted
# - STI: No timezone found, symbol may be delisted
# - CCE: No data found for this date range, symbol may be delisted
# - LO: No data found for this date range, symbol may be delisted
# - CEPH: No data found for this date range, symbol may be delisted
# - CHK: Data doesn't exist for startDate = 1133413200, endDate = 1262235600
# - DNR: No timezone found, symbol may be delisted
# - CFN: No data found for this date range, symbol may be delisted
# - DTV: No timezone found, symbol may be delisted
# - SUN: Data doesn't exist for startDate = 1133413200, endDate = 1262235600
# - CSC: No data found for this date range, symbol may be delisted
# - FLIR: No timezone found, symbol may be delisted
# C:\Users\Philip\anaconda3\lib\site-packages\pandas\core\internals\blocks.py:351: RuntimeWarning: invalid value encountered in log
#   result = func(self.values, **kwargs)
# (36, 360)
# AIG    -1.243570
# AMD    -0.883631
# MBI    -0.880274
# GNW    -0.816254
# ODP    -0.784961
# EP     -0.687141
# TGNA   -0.639192
# THC    -0.632083
# LEN    -0.628103
# C      -0.613125
# dtype: float64
# ['AIG', 'AMD', 'MBI', 'GNW', 'ODP', 'EP', 'TGNA', 'THC', 'LEN', 'C']
# 1.0292663891139375
# [-0.14769898692233838, 0.3996787968108296, -0.04495962534446742, 0.15940032978101673, -0.11921808577143563, 0.15515753777816654, 0.39659759277471024, -0.4257314298598701, -0.039758450681377316, 0.700061942044664, 0.3793355484974283, -0.23446749430007718, 0.40696873907937126, 1.0292663891139375]
# ['2007', 'MMM', 'BBBY', 'ABT', 'FII', 'MI', 'PLL', 'ADM', 'ADBE', 'ADP', 'FDO', 'AES', 'AFL', 'A', 'APD', 'AKAM', 'SNDK', 'TE', 'FSLR', 'TDC', 'JCP', 'GAS', 'ALL', 'GOOG', 'MO', 'AMZN', 'MAT', 'URBN', 'AEE', 'AGN', 'AEP', 'AXP', 'AIG', 'AMT', 'CNX', 'AMP', 'ABC', 'CVG', 'AMGN', 'APH', 'ADI', 'R', 'AON', 'APA', 'AAPL', 'AMAT', 'APTV', 'MON', 'MOLX', 'CCE', 'AIZ', 'T', 'NYT', 'ADSK', 'AZO', 'AVB', 'AVY', 'SCG', 'BKR', 'BALL', 'BAC', 'BBWI', 'BAX', 'BDX', 'VIAB', 'BRK-B', 'BBY', 'ANF', 'AET', 'BIIB', 'GENZ', 'BK', 'BA', 'BKNG', 'CFC', 'BXP', 'BSX', 'BMY', 'LSI', 'RRC', 'NOV', 'BF-B', 'LEG', 'CHRW', 'SPLS', 'NBL', 'PBCT', 'CPB', 'COF', 'CAH', 'XTO', 'CCL', 'RTN', 'KSS', 'CAT', 'PBI', 'CBRE', 'TSS', 'ESRX', 'GR', 'CNP', 'UNM', 'CF', 'FLIR', 'SCHW', 'EMC', 'CVX', 'NOVL', 'MIL', 'ALTR', 'CI', 'CINF', 'CTAS', 'CSCO', 'C', 'PCP', 'CLX', 'CME', 'CMS', 'KO', 'CTSH', 'CL', 'CMCSA', 'CMA', 'CAG', 'COP', 'ED', 'STZ', 'GPS', 'HOT', 'DPS', 'GLW', 'FLR', 'BIG', 'COST', 'CTRA', 'CEG', 'CSX', 'CMI', 'CVS', 'DHI', 'DHR', 'DRI', 'DVA', 'DE', 'BMC', 'XRAY', 'DVN', 'AGN', 'SRCL', 'TWC', 'DFS', 'LLTC', 'DIS', 'JNS', 'WFR', 'D', 'CPRI', 'DOV', 'AN', 'DTE', 'DUK', 'DOW', 'SWN', 'EMN', 'ETN', 'EBAY', 'ECL', 'EIX', 'Q', 'EA', 'ELV', 'LLY', 'EMR', 'TIF', 'ETR', 'EOG', 'DF', 'DELL', 'EFX', 'DNR', 'EQR', 'KBH', 'EL', 'HRB', 'DYN', 'SLM', 'ES', 'EXC', 'EXPE', 'EXPD', 'ACE', 'XOM', 'EK', 'WU', 'LUMN', 'FNM', 'BRCM', 'FDX', 'FITB', 'KG', 'FE', 'FIS', 'FISV', 'TWX', 'CTX', 'F', 'LM', 'ATI', 'FOXA', 'BEN', 'FCX', 'RRD', 'DNB', 'VNO', 'GEN', 'XRX', 'GD', 'GE', 'GIS', 'HNZ', 'GPC', 'GILD', 'GL', 'GME', 'GS', 'HAL', 'HIG', 'HAS', 'SWY', 'PEAK', 'CFN', 'HSY', 'HES', 'HCBK', 'YHOO', 'POM', 'HD', 'HON', 'ACAS', 'HST', 'AA', 'HPQ', 'HUM', 'HBAN', 'BCR', 'IBM', 'CAM', 'STJ', 'ITW', 'SIAL', 'SE', 'IGT', 'PDCO', 'INTC', 'ICE', 'IFF', 'IP', 'IPG', 'INTU', 'ISRG', 'IVZ', 'NBR', 'IQV', 'IRM', 'TEG', 'EQT', 'J', 'JNJ', 'JCI', 'JPM', 'JNPR', 'K', 'KEY', 'CA', 'KMB', 'KIM', 'EP', 'KLAC', 'OMX', 'KR', 'LEH', 'LH', 'NVLS', 'COL', 'CHK', 'APC', 'LEN', 'LNC', 'LIN', 'FRX', 'CBE', 'LMT', 'L', 'LOW', 'SHLD', 'MTB', 'MRO', 'RSH', 'LLL', 'MAR', 'MMC', 'X', 'MAS', 'MA', 'MWW', 'MKC', 'MCD', 'MCK', 'MDT', 'MRK', 'TER', 'MET', 'SII', 'RAI', 'MCHP', 'MU', 'MSFT', 'WB', 'MMI', 'JDSU', 'TGNA', 'TAP', 'MDLZ', 'COV', 'SLE', 'MCO', 'MS', 'NSM', 'MSI', 'CSC', 'NDAQ', 'NTAP', 'ODP', 'NWL', 'NEM', 'APOL', 'NEE', 'NKE', 'NI', 'XLNX', 'NSC', 'NTRS', 'NOC', 'JBL', 'NRG', 'NUE', 'NVDA', 'JEF', 'FLS', 'ORLY', 'OXY', 'STI', 'OMC', 'SNI', 'OKE', 'ORCL', 'LXK', 'M', 'PCAR', 'MUR', 'PARA', 'PH', 'PAYX', 'XL', 'NE', 'DV', 'PEP', 'PFE', 'CTXS', 'PM', 'SVU', 'PNW', 'PXD', 'PNC', 'ETFC', 'PPG', 'PPL', 'PFG', 'PG', 'PGR', 'PLD', 'PRU', 'PEG', 'VAR', 'PSA', 'PHM', 'ABK', 'PWR', 'QCOM', 'DGX', 'RL', 'FTR', 'RTX', 'WIN', 'MFE', 'PCS', 'RF', 'RSG', 'RDC', 'RVTY', 'RHI', 'ROK', 'ANDV', 'ROP', 'MBI', 'BMS', 'SPGI', 'FRE', 'DD', 'SLB', 'PGN', 'SEE', 'SRE', 'CELG', 'SHW', 'SPG', 'SUN', 'SJM', 'SNA', 'AVP', 'SO', 'LUV', 'SWK', 'SBUX', 'STT', 'WYN', 'CVH', 'SYK', 'GNW', 'HAR', 'SYY', 'RHT', 'TROW', 'DTV', 'TPR', 'S', 'TGT', 'CEPH', 'HOG', 'PCG', 'DO', 'AIV', 'TXN', 'TXT', 'TMO', 'TJX', 'LIFE', 'TT', 'STR', 'TRV', 'PCL', 'TFC', 'JWN', 'TSN', 'USB', 'CPWR', 'THC', 'UNP', 'HSP', 'UPS', 'BTU', 'UNH', 'GHC', 'VLO', 'JNY', 'VRSN', 'AYE', 'VZ', 'AMD', 'VFC', 'VTRS', 'BJS', 'CIEN', 'VMC', 'GT', 'WBA', 'WMT', 'WBD', 'WM', 'WAT', 'WEC', 'WFC', 'WELL', 'RX', 'WDC', 'WRK', 'WY', 'WHR', 'WMB', 'MHS', 'GWW', 'WYNN', 'XEL', 'ITT', 'YUM', 'TLAB', 'ZBH', 'ZION', 'FHN', 'WFM', 'BEAM', 'NYX', 'TIE', 'PTV', 'SGP', 'BC']
#
# 141 Failed downloads:
# - SNDK: No data found for this date range, symbol may be delisted
# - Q: No data found for this date range, symbol may be delisted
# - DYN: Data doesn't exist for startDate = 1101877200, endDate = 1230699600
# - NOVL: No data found for this date range, symbol may be delisted
# - HCBK: No data found for this date range, symbol may be delisted
# - ETFC: No timezone found, symbol may be delisted
# - LLTC: No data found for this date range, symbol may be delisted
# - PCL: No data found for this date range, symbol may be delisted
# - SE: Data doesn't exist for startDate = 1101877200, endDate = 1230699600
# - AYE: No data found for this date range, symbol may be delisted
# - VIAB: No timezone found, symbol may be delisted
# - GAS: Data doesn't exist for startDate = 1101877200, endDate = 1230699600
# - MMI: Data doesn't exist for startDate = 1101877200, endDate = 1230699600
# - TLAB: No data found for this date range, symbol may be delisted
# - LXK: No data found for this date range, symbol may be delisted
# - PTV: Data doesn't exist for startDate = 1101877200, endDate = 1230699600
# - WYN: No data found for this date range, symbol may be delisted
# - BJS: No data found for this date range, symbol may be delisted
# - MHS: No data found for this date range, symbol may be delisted
# - ACAS: No data found for this date range, symbol may be delisted
# - BEAM: Data doesn't exist for startDate = 1101877200, endDate = 1230699600
# - SPLS: No data found for this date range, symbol may be delisted
# - CPRI: Data doesn't exist for startDate = 1101877200, endDate = 1230699600
# - NE: Data doesn't exist for startDate = 1101877200, endDate = 1230699600
# - 2007: No timezone found, symbol may be delisted
# - FII: No timezone found, symbol may be delisted
# - CEG: Data doesn't exist for startDate = 1101877200, endDate = 1230699600
# - ALTR: Data doesn't exist for startDate = 1101877200, endDate = 1230699600
# - WIN: No timezone found, symbol may be delisted
# - DF: No timezone found, symbol may be delisted
# - LEH: No data found for this date range, symbol may be delisted
# - PCS: No data found for this date range, symbol may be delisted
# - FTR: No timezone found, symbol may be delisted
# - NVLS: No data found for this date range, symbol may be delisted
# - DELL: Data doesn't exist for startDate = 1101877200, endDate = 1230699600
# - JNY: No data found for this date range, symbol may be delisted
# - CPWR: Data doesn't exist for startDate = 1101877200, endDate = 1230699600
# - LM: No timezone found, symbol may be delisted
# - GENZ: No data found for this date range, symbol may be delisted
# - STR: Data doesn't exist for startDate = 1101877200, endDate = 1230699600
# - PGN: No data found for this date range, symbol may be delisted
# - MI: Data doesn't exist for startDate = 1101877200, endDate = 1230699600
# - FISV: Data doesn't exist for startDate = 1101877200, endDate = 1230699600
# - CELG: No timezone found, symbol may be delisted
# - BRCM: No data found for this date range, symbol may be delisted
# - DV: Data doesn't exist for startDate = 1101877200, endDate = 1230699600
# - RAI: No data found for this date range, symbol may be delisted
# - JDSU: No data found for this date range, symbol may be delisted
# - COV: No data found for this date range, symbol may be delisted
# - APOL: No data found for this date range, symbol may be delisted
# - XLNX: No timezone found, symbol may be delisted
# - SII: Data doesn't exist for startDate = 1101877200, endDate = 1230699600
# - ACE: Data doesn't exist for startDate = 1101877200, endDate = 1230699600
# - APTV: Data doesn't exist for startDate = 1101877200, endDate = 1230699600
# - RRD: No timezone found, symbol may be delisted
# - NSM: Data doesn't exist for startDate = 1101877200, endDate = 1230699600
# - MFE: Data doesn't exist for startDate = 1101877200, endDate = 1230699600
# - IQV: Data doesn't exist for startDate = 1101877200, endDate = 1230699600
# - PLL: Data doesn't exist for startDate = 1101877200, endDate = 1230699600
# - NYX: No timezone found, symbol may be delisted
# - FOXA: Data doesn't exist for startDate = 1101877200, endDate = 1230699600
# - JNS: No data found for this date range, symbol may be delisted
# - AVP: No timezone found, symbol may be delisted
# - FRX: No timezone found, symbol may be delisted
# - XTO: No data found for this date range, symbol may be delisted
# - SIAL: No data found for this date range, symbol may be delisted
# - SGP: No data found for this date range, symbol may be delisted
# - SLE: Data doesn't exist for startDate = 1101877200, endDate = 1230699600
# - DPS: No data found for this date range, symbol may be delisted
# - RSH: No data found for this date range, symbol may be delisted
# - TE: No data found for this date range, symbol may be delisted
# - EMC: Data doesn't exist for startDate = 1101877200, endDate = 1230699600
# - CVH: Data doesn't exist for startDate = 1101877200, endDate = 1230699600
# - FNM: No data found for this date range, symbol may be delisted
# - COL: No data found for this date range, symbol may be delisted
# - LLL: No timezone found, symbol may be delisted
# - CFC: No data found for this date range, symbol may be delisted
# - SWY: No data found for this date range, symbol may be delisted
# - SCG: Data doesn't exist for startDate = 1101877200, endDate = 1230699600
# - VAR: No timezone found, symbol may be delisted
# - MON: No timezone found, symbol may be delisted
# - HOT: Data doesn't exist for startDate = 1101877200, endDate = 1230699600
# - RTN: No timezone found, symbol may be delisted
# - YHOO: No data found for this date range, symbol may be delisted
# - DNB: Data doesn't exist for startDate = 1101877200, endDate = 1230699600
# - CBE: No data found for this date range, symbol may be delisted
# - HSP: No data found for this date range, symbol may be delisted
# - TEG: Data doesn't exist for startDate = 1101877200, endDate = 1230699600
# - XL: No timezone found, symbol may be delisted
# - BCR: No data found for this date range, symbol may be delisted
# - RDC: No timezone found, symbol may be delisted
# - SHLD: Data doesn't exist for startDate = 1101877200, endDate = 1230699600
# - BTU: Data doesn't exist for startDate = 1101877200, endDate = 1230699600
# - NBL: No timezone found, symbol may be delisted
# - TSS: No timezone found, symbol may be delisted
# - BMC: No data found for this date range, symbol may be delisted
# - DOW: Data doesn't exist for startDate = 1101877200, endDate = 1230699600
# - DO: Data doesn't exist for startDate = 1101877200, endDate = 1230699600
# - MOLX: No data found for this date range, symbol may be delisted
# - CAM: No data found for this date range, symbol may be delisted
# - TIE: No data found for this date range, symbol may be delisted
# - POM: Data doesn't exist for startDate = 1101877200, endDate = 1230699600
# - HAR: Data doesn't exist for startDate = 1101877200, endDate = 1230699600
# - S: Data doesn't exist for startDate = 1101877200, endDate = 1230699600
# - WFM: No data found for this date range, symbol may be delisted
# - MWW: No data found for this date range, symbol may be delisted
# - CTXS: No timezone found, symbol may be delisted
# - PBCT: No timezone found, symbol may be delisted
# - OMX: No data found for this date range, symbol may be delisted
# - EK: No data found for this date range, symbol may be delisted
# - JCP: No timezone found, symbol may be delisted
# - WRK: Data doesn't exist for startDate = 1101877200, endDate = 1230699600
# - WFR: No data found for this date range, symbol may be delisted
# - STJ: No data found for this date range, symbol may be delisted
# - APC: No timezone found, symbol may be delisted
# - TIF: No timezone found, symbol may be delisted
# - PCP: Data doesn't exist for startDate = 1101877200, endDate = 1230699600
# - LIFE: Data doesn't exist for startDate = 1101877200, endDate = 1230699600
# - GR: No data found for this date range, symbol may be delisted
# - HNZ: No data found for this date range, symbol may be delisted
# - CTX: No data found for this date range, symbol may be delisted
# - TWC: No data found for this date range, symbol may be delisted
# - MIL: No data found for this date range, symbol may be delisted
# - KG: No data found for this date range, symbol may be delisted
# - AGN: No timezone found, symbol may be delisted
# - RX: No data found for this date range, symbol may be delisted
# - RHT: No timezone found, symbol may be delisted
# - FDO: No data found for this date range, symbol may be delisted
# - WB: Data doesn't exist for startDate = 1101877200, endDate = 1230699600
# - STI: No timezone found, symbol may be delisted
# - CCE: No data found for this date range, symbol may be delisted
# - ABK: No data found for this date range, symbol may be delisted
# - FRE: Data doesn't exist for startDate = 1101877200, endDate = 1230699600
# - CEPH: No data found for this date range, symbol may be delisted
# - CHK: Data doesn't exist for startDate = 1101877200, endDate = 1230699600
# - DNR: No timezone found, symbol may be delisted
# - CFN: No data found for this date range, symbol may be delisted
# - DTV: No timezone found, symbol may be delisted
# - SUN: Data doesn't exist for startDate = 1101877200, endDate = 1230699600
# - CSC: No data found for this date range, symbol may be delisted
# - FLIR: No timezone found, symbol may be delisted
# (36, 351)
# MBI   -0.388040
# BSX   -0.372451
# LEN   -0.370370
# PHM   -0.364300
# AMD   -0.359016
# JCI   -0.337294
# BC    -0.334215
# SLM   -0.309575
# KBH   -0.274557
# THC   -0.256921
# dtype: float64
# ['MBI', 'BSX', 'LEN', 'PHM', 'AMD', 'JCI', 'BC', 'SLM', 'KBH', 'THC']
# -0.7192004513693478
# [-0.14769898692233838, 0.3996787968108296, -0.04495962534446742, 0.15940032978101673, -0.11921808577143563, 0.15515753777816654, 0.39659759277471024, -0.4257314298598701, -0.039758450681377316, 0.700061942044664, 0.3793355484974283, -0.23446749430007718, 0.40696873907937126, 1.0292663891139375, -0.7192004513693478]
# C:\Users\Philip\anaconda3\lib\site-packages\pandas\core\internals\blocks.py:351: RuntimeWarning: invalid value encountered in log
#   result = func(self.values, **kwargs)

# %% [markdown]
# After backtesting, the mean, annualised continuously compounding "holding period return" of each of the 11 strategy is as follows (all corrected to 3 significant figures):
# 1. Strategy 1: 0.122
# 2. Strategy 2: 0.132
# 3. Strategy 3: 0.135
# 4. Strategy 4: 0.0855
# 5. Strategy 5: 0.0565
# 6. Strategy 6: 0.0816
# 7. Strategy 7: 0.138
# 8. Srategy 8: 0.0638
# 9. Strategy 9: 0.0969
# 1. Strategy 10: 0.0732
# 2. Strategy 11: 0.0917
#
# As a comparison, the annualised continuously compounding return of S&P 500 index is 0.0840.
#
# Please bear in mind that, a strategy with a mean return higher than that of S&P 500 index does not necessary mean that it is better than investing in S&P 500, because most of these strategies have a higher Beta and high volatility (standard deviation of return) than S&P 500. This means that the Sharpe ratio of these strategies may not be higher (actually, most of them has a lower Sharpe ratio) than that of S&P 500.

# %%
with pd.ExcelWriter('Backtests_by_Python.xlsx') as writer:  
    st.to_excel(writer, sheet_name='s')
    ri.to_excel(writer, sheet_name='r')
    mean.to_excel(writer, sheet_name='miu')

# %%
fout.close()
